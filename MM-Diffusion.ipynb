# %%
# !pip install torchvision==0.16.2+cu121 --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# Collecting torchvision==0.16.2+cu121
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.16.2%2Bcu121-cp310-cp310-linux_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.2+cu121) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.2+cu121) (2.32.3)
# Collecting torch==2.1.2 (from torchvision==0.16.2+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.1.2%2Bcu121-cp310-cp310-linux_x86_64.whl (2200.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 701.7 kB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.2+cu121) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->torchvision==0.16.2+cu121) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->torchvision==0.16.2+cu121) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->torchvision==0.16.2+cu121) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->torchvision==0.16.2+cu121) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->torchvision==0.16.2+cu121) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->torchvision==0.16.2+cu121) (2024.10.0)
# Collecting triton==2.1.0 (from torch==2.1.2->torchvision==0.16.2+cu121)
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.2+cu121) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.2+cu121) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.2+cu121) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.2+cu121) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.2->torchvision==0.16.2+cu121) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.2->torchvision==0.16.2+cu121) (1.3.0)
# Installing collected packages: triton, torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.1.2+cu121 which is incompatible.
# Successfully installed torch-2.1.2+cu121 torchvision-0.16.2+cu121 triton-2.1.0

# %%
# !pip install mpi4py
# Out:
# Collecting mpi4py
#   Downloading mpi4py-4.0.1.tar.gz (466 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.2/466.2 kB 12.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: mpi4py
#   Building wheel for mpi4py (pyproject.toml) ... done
#   Created wheel for mpi4py: filename=mpi4py-4.0.1-cp310-cp310-linux_x86_64.whl size=4266344 sha256=c13042f54766550814413ba79f4dd711bfefa04b3c4e730a072f4b9a470c0f62
#   Stored in directory: /root/.cache/pip/wheels/3c/ca/13/13218a83854023ccec184e3af482f0f038b434aa32c19afee8
# Successfully built mpi4py
# Installing collected packages: mpi4py
# Successfully installed mpi4py-4.0.1

# %%
# !pip install librosa==0.10.0
# Out:
# Collecting librosa==0.10.0
#   Downloading librosa-0.10.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (3.0.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa==0.10.0) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa==0.10.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.10.0) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.10.0) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa==0.10.0) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa==0.10.0) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.0) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0) (2024.8.30)
# Downloading librosa-0.10.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.9/252.9 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: librosa
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# Successfully installed librosa-0.10.0

# %%
# !pip install lpips==0.1.4
# Out:
# Collecting lpips==0.1.4
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (2.1.2+cu121)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (0.16.2+cu121)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (1.26.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (1.13.1)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (4.66.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2024.10.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips==0.1.4) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips==0.1.4) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->lpips==0.1.4) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips==0.1.4) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips==0.1.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips==0.1.4) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips==0.1.4) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.0->lpips==0.1.4) (1.3.0)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %%
# !pip install mkl-fft==1.3.6
# Out:
# Collecting mkl-fft==1.3.6
#   Downloading mkl_fft-1.3.6-58-cp310-cp310-manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting numpy<1.25.0,>=1.24.3 (from mkl-fft==1.3.6)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from mkl-fft==1.3.6) (2025.0.0)
# Collecting dpcpp_cpp_rt (from mkl-fft==1.3.6)
#   Downloading dpcpp_cpp_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Collecting intel-opencl-rt==2025.0.1 (from dpcpp_cpp_rt->mkl-fft==1.3.6)
#   Downloading intel_opencl_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting intel-openmp==2025.0.1 (from dpcpp_cpp_rt->mkl-fft==1.3.6)
#   Downloading intel_openmp-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting intel-sycl-rt==2025.0.1 (from dpcpp_cpp_rt->mkl-fft==1.3.6)
#   Downloading intel_sycl_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from intel-opencl-rt==2025.0.1->dpcpp_cpp_rt->mkl-fft==1.3.6) (2022.0.0)
# Collecting intel-cmplr-lic-rt==2025.* (from intel-opencl-rt==2025.0.1->dpcpp_cpp_rt->mkl-fft==1.3.6)
#   Downloading intel_cmplr_lic_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting intel-cmplr-lib-ur==2025.0.1 (from intel-openmp==2025.0.1->dpcpp_cpp_rt->mkl-fft==1.3.6)
#   Downloading intel_cmplr_lib_ur-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting intel-cmplr-lib-rt==2025.0.1 (from intel-sycl-rt==2025.0.1->dpcpp_cpp_rt->mkl-fft==1.3.6)
#   Downloading intel_cmplr_lib_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: umf==0.9 in /usr/local/lib/python3.10/dist-packages (from intel-cmplr-lib-ur==2025.0.1->intel-openmp==2025.0.1->dpcpp_cpp_rt->mkl-fft==1.3.6) (0.9.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->intel-opencl-rt==2025.0.1->dpcpp_cpp_rt->mkl-fft==1.3.6) (1.2.0)
# Downloading mkl_fft-1.3.6-58-cp310-cp310-manylinux2014_x86_64.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.2/220.2 kB 6.5 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 56.8 MB/s eta 0:00:00
# Downloading dpcpp_cpp_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (28 kB)
# Downloading intel_opencl_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (194.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.0/194.0 MB 6.1 MB/s eta 0:00:00
# Downloading intel_openmp-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (30.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 56.1 MB/s eta 0:00:00
# Downloading intel_sycl_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 78.7 MB/s eta 0:00:00
# Downloading intel_cmplr_lib_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (45.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 15.4 MB/s eta 0:00:00
# Downloading intel_cmplr_lib_ur-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (25.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 74.4 MB/s eta 0:00:00
# Downloading intel_cmplr_lic_rt-2025.0.1-py2.py3-none-manylinux_2_28_x86_64.whl (18 kB)
# Installing collected packages: intel-cmplr-lic-rt, intel-cmplr-lib-rt, numpy, intel-opencl-rt, intel-cmplr-lib-ur, intel-sycl-rt, intel-openmp, dpcpp_cpp_rt, mkl-fft
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: intel-cmplr-lib-ur
#     Found existing installation: intel-cmplr-lib-ur 2025.0.0
#     Uninstalling intel-cmplr-lib-ur-2025.0.0:
#       Successfully uninstalled intel-cmplr-lib-ur-2025.0.0
#   Attempting uninstall: intel-openmp
#     Found existing installation: intel-openmp 2025.0.0
#     Uninstalling intel-openmp-2025.0.0:
#       Successfully uninstalled intel-openmp-2025.0.0
# Successfully installed dpcpp_cpp_rt-2025.0.1 intel-cmplr-lib-rt-2025.0.1 intel-cmplr-lib-ur-2025.0.1 intel-cmplr-lic-rt-2025.0.1 intel-opencl-rt-2025.0.1 intel-openmp-2025.0.1 intel-sycl-rt-2025.0.1 mkl-fft-1.3.6 numpy-1.24.4

# %%
# !pip install mkl-random==1.2.2
# Out:
# Requirement already satisfied: mkl-random==1.2.2 in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy<1.25.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from mkl-random==1.2.2) (1.24.4)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from mkl-random==1.2.2) (2025.0.0)
# Requirement already satisfied: dpcpp_cpp_rt in /usr/local/lib/python3.10/dist-packages (from mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: intel-opencl-rt==2025.0.1 in /usr/local/lib/python3.10/dist-packages (from dpcpp_cpp_rt->mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: intel-openmp==2025.0.1 in /usr/local/lib/python3.10/dist-packages (from dpcpp_cpp_rt->mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: intel-sycl-rt==2025.0.1 in /usr/local/lib/python3.10/dist-packages (from dpcpp_cpp_rt->mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from intel-opencl-rt==2025.0.1->dpcpp_cpp_rt->mkl-random==1.2.2) (2022.0.0)
# Requirement already satisfied: intel-cmplr-lic-rt==2025.* in /usr/local/lib/python3.10/dist-packages (from intel-opencl-rt==2025.0.1->dpcpp_cpp_rt->mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.1 in /usr/local/lib/python3.10/dist-packages (from intel-openmp==2025.0.1->dpcpp_cpp_rt->mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: intel-cmplr-lib-rt==2025.0.1 in /usr/local/lib/python3.10/dist-packages (from intel-sycl-rt==2025.0.1->dpcpp_cpp_rt->mkl-random==1.2.2) (2025.0.1)
# Requirement already satisfied: umf==0.9 in /usr/local/lib/python3.10/dist-packages (from intel-cmplr-lib-ur==2025.0.1->intel-openmp==2025.0.1->dpcpp_cpp_rt->mkl-random==1.2.2) (0.9.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->intel-opencl-rt==2025.0.1->dpcpp_cpp_rt->mkl-random==1.2.2) (1.2.0)

# %%
# !pip install mkl-service==2.4.0
# Out:
# Collecting mkl-service==2.4.0
#   Downloading mkl_service-2.4.0-35-cp310-cp310-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from mkl-service==2.4.0) (2025.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mkl-service==2.4.0) (1.16.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->mkl-service==2.4.0) (2025.0.1)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->mkl-service==2.4.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->mkl-service==2.4.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.1 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->mkl-service==2.4.0) (2025.0.1)
# Requirement already satisfied: umf==0.9 in /usr/local/lib/python3.10/dist-packages (from intel-cmplr-lib-ur==2025.0.1->intel-openmp>=2024->mkl->mkl-service==2.4.0) (0.9.0)
# Downloading mkl_service-2.4.0-35-cp310-cp310-manylinux2014_x86_64.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: mkl-service
# Successfully installed mkl-service-2.4.0

# %%
# !pip install -r /content/drive/MyDrive/MM-Diffusion/requirement.txt
# Out:
# Collecting appdirs==1.4.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 1))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting audioread==3.0.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 2))
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av==10.0.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 3))
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting blobfile==2.0.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 4))
#   Downloading blobfile-2.0.1-py3-none-any.whl.metadata (14 kB)
# Collecting brotlipy==0.7.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 5))
#   Downloading brotlipy-0.7.0-cp35-abi3-manylinux2010_x86_64.whl.metadata (2.9 kB)
# Collecting certifi==2022.12.7 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 6))
#   Downloading certifi-2022.12.7-py3-none-any.whl.metadata (2.9 kB)
# Collecting cffi==1.15.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 7))
#   Downloading cffi-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting charset-normalizer==2.0.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 8))
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl.metadata (11 kB)
# Collecting click==8.1.3 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 9))
#   Downloading click-8.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting cryptography==39.0.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 10))
#   Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 11)) (4.4.2)
# Requirement already satisfied: docker-pycreds==0.4.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 12)) (0.4.0)
# Collecting einops==0.6.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 13))
#   Downloading einops-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting einops-exts==0.0.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 14))
#   Downloading einops_exts-0.0.4-py3-none-any.whl.metadata (621 bytes)
# Collecting filelock==3.9.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 15))
#   Downloading filelock-3.9.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting flit_core==3.6.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 16))
#   Downloading flit_core-3.6.0-py3-none-any.whl.metadata (401 bytes)
# Collecting ftfy==6.1.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 17))
#   Downloading ftfy-6.1.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting gitdb==4.0.10 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 18))
#   Downloading gitdb-4.0.10-py3-none-any.whl.metadata (1.1 kB)
# Collecting GitPython==3.1.31 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 19))
#   Downloading GitPython-3.1.31-py3-none-any.whl.metadata (1.3 kB)
# Collecting idna==3.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 20))
#   Downloading idna-3.4-py3-none-any.whl.metadata (9.8 kB)
# Collecting imageio==2.26.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 21))
#   Downloading imageio-2.26.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting imageio-ffmpeg==0.4.8 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 22))
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl.metadata (1.6 kB)
# Collecting importlib-metadata==6.0.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 23))
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting joblib==1.2.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 24))
#   Downloading joblib-1.2.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting jsonpatch==1.32 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 25))
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting jsonpointer==2.3 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 26))
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting lazy_loader==0.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 27))
#   Downloading lazy_loader-0.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting llvmlite==0.39.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 28))
#   Downloading llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Collecting lxml==4.9.2 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 29))
#   Downloading lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: moviepy==1.0.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 30)) (1.0.3)
# Collecting msgpack==1.0.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 31))
#   Downloading msgpack-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Collecting networkx==3.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 32))
#   Downloading networkx-3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting numba==0.56.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 33))
#   Downloading numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy==1.23.5 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 34))
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting opencv-python==4.7.0.72 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 35))
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting opencv-python-headless==4.7.0.72 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 36))
#   Downloading opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting packaging==23.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 37))
#   Downloading packaging-23.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting pandas==1.5.3 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 38))
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pathtools==0.1.2 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 39))
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting Pillow==9.4.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 40))
#   Downloading Pillow-9.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.3 kB)
# Collecting pip==23.0.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 41))
#   Downloading pip-23.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting platformdirs==3.1.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 42))
#   Downloading platformdirs-3.1.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting pooch==1.7.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 43))
#   Downloading pooch-1.7.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: proglog==0.1.10 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 44)) (0.1.10)
# Collecting protobuf==4.22.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 45))
#   Downloading protobuf-4.22.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Collecting psutil==5.9.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 46))
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting pycparser==2.21 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 47))
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pycryptodomex==3.17 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 48))
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting pyOpenSSL==23.0.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 49))
#   Downloading pyOpenSSL-23.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 50)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 51)) (2.8.2)
# Collecting pytorch-ignite==0.4.11 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52))
#   Downloading pytorch_ignite-0.4.11-py3-none-any.whl.metadata (28 kB)
# Collecting pytz==2022.7.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 53))
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting PyYAML==6.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 54))
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.0 kB)
# Collecting regex==2022.10.31 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 55))
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.0 MB/s eta 0:00:00
# Collecting requests==2.28.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 56))
#   Downloading requests-2.28.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting scikit-learn==1.2.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 57))
#   Downloading scikit_learn-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.10.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 58))
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 5.1 MB/s eta 0:00:00
# Collecting sentry-sdk==1.16.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 59))
#   Downloading sentry_sdk-1.16.0-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting setproctitle==1.3.2 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 60))
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# Collecting setuptools==65.6.3 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 61))
#   Downloading setuptools-65.6.3-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 62)) (1.16.0)
# Collecting smmap==5.0.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 63))
#   Downloading smmap-5.0.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: soundfile==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 64)) (0.12.1)
# Collecting soxr==0.3.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 65))
#   Downloading soxr-0.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting termcolor==2.2.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 66))
#   Downloading termcolor-2.2.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting threadpoolctl==3.1.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 67))
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting tornado==6.2 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 68))
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting tqdm==4.65.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 69))
#   Downloading tqdm-4.65.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.3 MB/s eta 0:00:00
# Collecting typing_extensions==4.4.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 70))
#   Downloading typing_extensions-4.4.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting urllib3==1.26.14 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 71))
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 4.0 MB/s eta 0:00:00
# Collecting visdom==0.2.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 72))
#   Downloading visdom-0.2.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 46.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wandb==0.13.11 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 73))
#   Downloading wandb-0.13.11-py3-none-any.whl.metadata (7.9 kB)
# Collecting wcwidth==0.2.6 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 74))
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting websocket-client==1.5.1 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 75))
#   Downloading websocket_client-1.5.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting wheel==0.38.4 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 76))
#   Downloading wheel-0.38.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting xmltodict==0.13.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 77))
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting zipp==3.15.0 (from -r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 78))
#   Downloading zipp-3.15.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: torch<3,>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (2.1.2+cu121)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3,>=1.3->pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3,>=1.3->pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<3,>=1.3->pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (2024.10.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch<3,>=1.3->pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3,>=1.3->pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3,>=1.3->pytorch-ignite==0.4.11->-r /content/drive/MyDrive/MM-Diffusion/requirement.txt (line 52)) (1.3.0)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 48.8 MB/s eta 0:00:00
# Downloading blobfile-2.0.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 6.0 MB/s eta 0:00:00
# Downloading brotlipy-0.7.0-cp35-abi3-manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.7 MB/s eta 0:00:00
# Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 11.8 MB/s eta 0:00:00
# Downloading cffi-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.8/441.8 kB 30.5 MB/s eta 0:00:00
# Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Downloading click-8.1.3-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 8.4 MB/s eta 0:00:00
# Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 62.1 MB/s eta 0:00:00
# Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.7 MB/s eta 0:00:00
# Downloading einops_exts-0.0.4-py3-none-any.whl (3.9 kB)
# Downloading filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Downloading flit_core-3.6.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 5.1 MB/s eta 0:00:00
# Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.9 MB/s eta 0:00:00
# Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.8 MB/s eta 0:00:00
# Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.7 MB/s eta 0:00:00
# Downloading idna-3.4-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.8 MB/s eta 0:00:00
# Downloading imageio-2.26.0-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.4 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 27.0 MB/s eta 0:00:00
# Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 21.9 MB/s eta 0:00:00
# Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Downloading lazy_loader-0.1-py3-none-any.whl (8.6 kB)
# Downloading llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 14.9 MB/s eta 0:00:00
# Downloading lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 82.3 MB/s eta 0:00:00
# Downloading msgpack-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 kB 26.5 MB/s eta 0:00:00
# Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.5 MB/s eta 0:00:00
# Downloading numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 84.1 MB/s eta 0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 91.1 MB/s eta 0:00:00
# Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 10.7 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 13.5 MB/s eta 0:00:00
# Downloading packaging-23.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.7 MB/s eta 0:00:00
# Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 89.9 MB/s eta 0:00:00
# Downloading Pillow-9.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 81.1 MB/s eta 0:00:00
# Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.5 MB/s eta 0:00:00
# Downloading platformdirs-3.1.0-py3-none-any.whl (14 kB)
# Downloading pooch-1.7.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.5 MB/s eta 0:00:00
# Downloading protobuf-4.22.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 25.9 MB/s eta 0:00:00
# Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 24.1 MB/s eta 0:00:00
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 11.4 MB/s eta 0:00:00
# Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 75.7 MB/s eta 0:00:00
# Downloading pyOpenSSL-23.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 5.3 MB/s eta 0:00:00
# Downloading pytorch_ignite-0.4.11-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.5/266.5 kB 20.5 MB/s eta 0:00:00
# Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 32.5 MB/s eta 0:00:00
# Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 45.7 MB/s eta 0:00:00
# Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 50.2 MB/s eta 0:00:00
# Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 101.1 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 18.2 MB/s eta 0:00:00
# Downloading sentry_sdk-1.16.0-py2.py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 16.6 MB/s eta 0:00:00
# Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading setuptools-65.6.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.3 MB/s eta 0:00:00
# Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Downloading soxr-0.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.4 MB/s eta 0:00:00
# Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.0/424.0 kB 32.5 MB/s eta 0:00:00
# Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 12.4 MB/s eta 0:00:00
# Downloading wandb-0.13.11-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 76.2 MB/s eta 0:00:00
# Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.9 MB/s eta 0:00:00
# Downloading wheel-0.38.4-py3-none-any.whl (36 kB)
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Building wheels for collected packages: audioread, pathtools, visdom
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=dcc8b8c039a53d9b50ba4293deff50a47e201ca26f3930eb8a1480ca920b982e
#   Stored in directory: /root/.cache/pip/wheels/da/4b/39/c5f6c4ee93b43281dda4dab5ac5f2bdf9d11074d427493cd55
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8793 sha256=e847748c8e73c81bc5583ccee1177e42405114f34f7ae0f4ea8150abc7bf7836
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408196 sha256=40ab91bff9054019d891b69898ed405e587f0e7aa9b3e47b6869adba2a3afc4e
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# Successfully built audioread pathtools visdom
# Installing collected packages: wcwidth, pytz, pathtools, msgpack, av, appdirs, zipp, xmltodict, wheel, websocket-client, urllib3, typing_extensions, tqdm, tornado, threadpoolctl, termcolor, smmap, setuptools, setproctitle, regex, PyYAML, pycryptodomex, pycparser, psutil, protobuf, platformdirs, pip, Pillow, packaging, numpy, networkx, lxml, llvmlite, lazy_loader, jsonpointer, joblib, imageio-ffmpeg, idna, ftfy, flit_core, filelock, einops, click, charset-normalizer, certifi, audioread, soxr, sentry-sdk, scipy, requests, pandas, opencv-python-headless, opencv-python, numba, jsonpatch, importlib-metadata, imageio, gitdb, einops-exts, cffi, blobfile, visdom, scikit-learn, pooch, GitPython, cryptography, brotlipy, wandb, pytorch-ignite, pyOpenSSL
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.0
#     Uninstalling msgpack-1.1.0:
#       Successfully uninstalled msgpack-1.1.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.0
#     Uninstalling wheel-0.45.0:
#       Successfully uninstalled wheel-0.45.0
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.8.0
#     Uninstalling websocket-client-1.8.0:
#       Successfully uninstalled websocket-client-1.8.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.3
#     Uninstalling tornado-6.3.3:
#       Successfully uninstalled tornado-6.3.3
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.5.0
#     Uninstalling termcolor-2.5.0:
#       Successfully uninstalled termcolor-2.5.0
#   Attempting uninstall: smmap
#     Found existing installation: smmap 5.0.1
#     Uninstalling smmap-5.0.1:
#       Successfully uninstalled smmap-5.0.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: setproctitle
#     Found existing installation: setproctitle 1.3.4
#     Uninstalling setproctitle-1.3.4:
#       Successfully uninstalled setproctitle-1.3.4
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.9.11
#     Uninstalling regex-2024.9.11:
#       Successfully uninstalled regex-2024.9.11
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.22
#     Uninstalling pycparser-2.22:
#       Successfully uninstalled pycparser-2.22
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.3.6
#     Uninstalling platformdirs-4.3.6:
#       Successfully uninstalled platformdirs-4.3.6
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.0
#     Uninstalling lxml-5.3.0:
#       Successfully uninstalled lxml-5.3.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: lazy_loader
#     Found existing installation: lazy_loader 0.4
#     Uninstalling lazy_loader-0.4:
#       Successfully uninstalled lazy_loader-0.4
#   Attempting uninstall: jsonpointer
#     Found existing installation: jsonpointer 3.0.0
#     Uninstalling jsonpointer-3.0.0:
#       Successfully uninstalled jsonpointer-3.0.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.5.1
#     Uninstalling imageio-ffmpeg-0.5.1:
#       Successfully uninstalled imageio-ffmpeg-0.5.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.0
#     Uninstalling charset-normalizer-3.4.0:
#       Successfully uninstalled charset-normalizer-3.4.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.8.30
#     Uninstalling certifi-2024.8.30:
#       Successfully uninstalled certifi-2024.8.30
#   Attempting uninstall: audioread
#     Found existing installation: audioread 3.0.1
#     Uninstalling audioread-3.0.1:
#       Successfully uninstalled audioread-3.0.1
#   Attempting uninstall: soxr
#     Found existing installation: soxr 0.5.0.post1
#     Uninstalling soxr-0.5.0.post1:
#       Successfully uninstalled soxr-0.5.0.post1
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 2.18.0
#     Uninstalling sentry-sdk-2.18.0:
#       Successfully uninstalled sentry-sdk-2.18.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.10.0.84
#     Uninstalling opencv-python-headless-4.10.0.84:
#       Successfully uninstalled opencv-python-headless-4.10.0.84
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.33
#     Uninstalling jsonpatch-1.33:
#       Successfully uninstalled jsonpatch-1.33
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.36.0
#     Uninstalling imageio-2.36.0:
#       Successfully uninstalled imageio-2.36.0
#   Attempting uninstall: gitdb
#     Found existing installation: gitdb 4.0.11
#     Uninstalling gitdb-4.0.11:
#       Successfully uninstalled gitdb-4.0.11
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: pooch
#     Found existing installation: pooch 1.8.2
#     Uninstalling pooch-1.8.2:
#       Successfully uninstalled pooch-1.8.2
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.43
#     Uninstalling GitPython-3.1.43:
#       Successfully uninstalled GitPython-3.1.43
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.18.7
#     Uninstalling wandb-0.18.7:
#       Successfully uninstalled wandb-0.18.7
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# sqlalchemy 2.0.36 requires typing-extensions>=4.6.0, but you have typing-extensions 4.4.0 which is incompatible.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albucore 0.0.19 requires opencv-python-headless>=4.9.0.80, but you have opencv-python-headless 4.7.0.72 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.20 requires opencv-python-headless>=4.9.0.80, but you have opencv-python-headless 4.7.0.72 which is incompatible.
# bigframes 1.27.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# bigframes 1.27.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.2.1 which is incompatible.
# chex 0.1.87 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# cudf-cu12 24.10.1 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.1 which is incompatible.
# google-colab 1.0.0 requires tornado==6.3.3, but you have tornado 6.2 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# kaggle 1.6.17 requires certifi>=2023.7.22, but you have certifi 2022.12.7 which is incompatible.
# langchain-core 0.3.19 requires jsonpatch<2.0,>=1.33, but you have jsonpatch 1.32 which is incompatible.
# langchain-core 0.3.19 requires packaging<25,>=23.2, but you have packaging 23.0 which is incompatible.
# langchain-core 0.3.19 requires typing-extensions>=4.7, but you have typing-extensions 4.4.0 which is incompatible.
# mizani 0.13.0 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# mkl-fft 1.3.6 requires numpy<1.25.0,>=1.24.3, but you have numpy 1.23.5 which is incompatible.
# mkl-random 1.2.2 requires numpy<1.25.0,>=1.24.3, but you have numpy 1.23.5 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.1 which is incompatible.
# nibabel 5.3.2 requires typing-extensions>=4.6; python_version < "3.13", but you have typing-extensions 4.4.0 which is incompatible.
# openai 1.54.4 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.4.0 which is incompatible.
# optree 0.13.1 requires typing-extensions>=4.5.0, but you have typing-extensions 4.4.0 which is incompatible.
# plotnine 0.14.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# pydantic 2.9.2 requires typing-extensions>=4.6.1; python_version < "3.13", but you have typing-extensions 4.4.0 which is incompatible.
# pydantic-core 2.23.4 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.4.0 which is incompatible.
# pygit2 1.16.0 requires cffi>=1.17.0, but you have cffi 1.15.1 which is incompatible.
# pytensor 2.26.3 requires filelock>=3.15, but you have filelock 3.9.0 which is incompatible.
# rmm-cu12 24.10.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# scikit-image 0.24.0 requires imageio>=2.33, but you have imageio 2.26.0 which is incompatible.
# scikit-image 0.24.0 requires lazy-loader>=0.4, but you have lazy-loader 0.1 which is incompatible.
# simple-parsing 0.1.6 requires typing-extensions>=4.5.0, but you have typing-extensions 4.4.0 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.28.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.1.2+cu121 which is incompatible.
# typeguard 4.4.1 requires typing-extensions>=4.10.0, but you have typing-extensions 4.4.0 which is incompatible.
# xarray 2024.10.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.10.0 requires packaging>=23.1, but you have packaging 23.0 which is incompatible.
# xarray 2024.10.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# yfinance 0.2.49 requires requests>=2.31, but you have requests 2.28.1 which is incompatible.
# Successfully installed GitPython-3.1.31 Pillow-9.4.0 PyYAML-6.0 appdirs-1.4.4 audioread-3.0.0 av-10.0.0 blobfile-2.0.1 brotlipy-0.7.0 certifi-2022.12.7 cffi-1.15.1 charset-normalizer-2.0.4 click-8.1.3 cryptography-39.0.1 einops-0.6.0 einops-exts-0.0.4 filelock-3.9.0 flit_core-3.6.0 ftfy-6.1.1 gitdb-4.0.10 idna-3.4 imageio-2.26.0 imageio-ffmpeg-0.4.8 importlib-metadata-6.0.0 joblib-1.2.0 jsonpatch-1.32 jsonpointer-2.3 lazy_loader-0.1 llvmlite-0.39.1 lxml-4.9.2 msgpack-1.0.4 networkx-3.0 numba-0.56.4 numpy-1.23.5 opencv-python-4.7.0.72 opencv-python-headless-4.7.0.72 packaging-23.0 pandas-1.5.3 pathtools-0.1.2 pip-23.0.1 platformdirs-3.1.0 pooch-1.7.0 protobuf-4.22.1 psutil-5.9.4 pyOpenSSL-23.0.0 pycparser-2.21 pycryptodomex-3.17 pytorch-ignite-0.4.11 pytz-2022.7.1 regex-2022.10.31 requests-2.28.1 scikit-learn-1.2.1 scipy-1.10.1 sentry-sdk-1.16.0 setproctitle-1.3.2 setuptools-65.6.3 smmap-5.0.0 soxr-0.3.4 termcolor-2.2.0 threadpoolctl-3.1.0 tornado-6.2 tqdm-4.65.0 typing_extensions-4.4.0 urllib3-1.26.14 visdom-0.2.4 wandb-0.13.11 wcwidth-0.2.6 websocket-client-1.5.1 wheel-0.38.4 xmltodict-0.13.0 zipp-3.15.0

# %%
# !apt-get install -y libopenmpi-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopenmpi-dev is already the newest version (4.1.2-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import os

# Set environment variables to allow MPI to run as root
os.environ['OMPI_ALLOW_RUN_AS_ROOT'] = '1'
os.environ['OMPI_ALLOW_RUN_AS_ROOT_CONFIRM'] = '1'

# %%
MODEL_FLAGS="--cross_attention_resolutions 2,4,8 --cross_attention_windows 1,4,8 \
--cross_attention_shift True --dropout 0.1 \
--video_attention_resolutions 2,4,8 \
--audio_attention_resolutions -1 \
--video_size 16,3,64,64 --audio_size 1,25600 --learn_sigma False --num_channels 128 \
--num_head_channels 64 --num_res_blocks 2 --resblock_updown True --use_fp16 True \
--use_scale_shift_norm True --num_workers 8"

# Modify --devices to your own GPU ID
TRAIN_FLAGS="--lr 0.0001 --batch_size 7 \
--devices 0 --log_interval 100 --save_interval 5000 --use_db False \
--resume_checkpoint /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/model070000.pt" #--schedule_sampler loss-second-moment
DIFFUSION_FLAGS="--noise_schedule linear --diffusion_steps 1000 --save_type mp4 --sample_fn ddpm"

# Modify the following paths to your own paths
DATA_DIR="/content/drive/MyDrive/environmental/train"
OUTPUT_DIR="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/"
NUM_GPUS=1

# %%
# !mpiexec -n $NUM_GPUS python3 /content/drive/MyDrive/MM-Diffusion/py_scripts/multimodal_train.py \
    --data_dir $DATA_DIR --output_dir $OUTPUT_DIR $MODEL_FLAGS $TRAIN_FLAGS $DIFFUSION_FLAGS
# Out:
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Logging to /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/
# Effective parameters:
#   <<< audio_attention_resolutions: -1
#   <<< audio_fps: 16000
#   <<< audio_size: [1, 25600]
#   <<< audio_type: 1d
#   <<< batch_size: 7
#   <<< channel_mult:
#   <<< class_cond: False
#   <<< cross_attention_resolutions: 2,4,8
#   <<< cross_attention_shift: True
#   <<< cross_attention_windows: 1,4,8
#   <<< data_dir: /content/drive/MyDrive/environmental/train
#   <<< devices: 0
#   <<< diffusion_steps: 1000
#   <<< dropout: 0.1
#   <<< ema_rate: 0.9999
#   <<< fp16_scale_growth: 0.001
#   <<< frame_gap: 1
#   <<< learn_sigma: False
#   <<< log_interval: 100
#   <<< lr: 0.0001
#   <<< lr_anneal_steps: 0
#   <<< microbatch: -1
#   <<< noise_schedule: linear
#   <<< num_channels: 128
#   <<< num_head_channels: 64
#   <<< num_heads: 4
#   <<< num_heads_upsample: -1
#   <<< num_res_blocks: 2
#   <<< num_workers: 8
#   <<< output_dir: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/
#   <<< predict_xstart: False
#   <<< resblock_updown: True
#   <<< rescale_learned_sigmas: False
#   <<< rescale_timesteps: False
#   <<< resume_checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/model070000.pt
#   <<< sample_fn: ddpm
#   <<< save_interval: 5000
#   <<< save_type: mp4
#   <<< schedule_sampler: uniform
#   <<< seed: 42
#   <<< t_lr: 0.0001
#   <<< timestep_respacing:
#   <<< use_checkpoint: False
#   <<< use_db: False
#   <<< use_fp16: True
#   <<< use_kl: False
#   <<< use_scale_shift_norm: True
#   <<< video_attention_resolutions: 2,4,8
#   <<< video_fps: 10
#   <<< video_size: [16, 3, 64, 64]
#   <<< video_type: 2d+1d
#   <<< weight_decay: 0.0
# creating model and diffusion...
# creating data loader...
# continue training from step 70000
# loading model from checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/model070000.pt...
# loading optimizer state from checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/opt070000.pt
# loading EMA from checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ema_0.9999_070000.pt...
# Total Parameters:133.68M
# Total Training Parameters:133.68M
# Total Loaded Parameters:133.68M
# ******DDP sync model done...
# len(data loader):900
# load /content/drive/MyDrive/environmental/train/video_clip_f16_g1_r10.pkl...
# load 77449 video clips from /content/drive/MyDrive/environmental/train/video_clip_f16_g1_r10.pkl......
# Found NaN, decreased lg_loss_scale to 19.01600000000002
# ---------------------------------
# |openai-2024-11-18-13:42:37|
# | current_grad_norm  | 0.146    |
# | current_param_norm | 376      |
# | grad_norm          | 0.112    |
# | lg_loss_scale      | 19.2     |
# | loss               | 0.0198   |
# | loss_q0            | 0.0749   |
# | loss_q1            | 0.00669  |
# | loss_q2            | 0.00106  |
# | loss_q3            | 0.000241 |
# | mse_audio          | 0.0103   |
# | mse_audio_q0       | 0.041    |
# | mse_audio_q1       | 0.00197  |
# | mse_audio_q2       | 0.000218 |
# | mse_audio_q3       | 8.3e-05  |
# | mse_video          | 0.0095   |
# | mse_video_q0       | 0.0339   |
# | mse_video_q1       | 0.00472  |
# | mse_video_q2       | 0.000843 |
# | mse_video_q3       | 0.000158 |
# | param_norm         | 376      |
# | samples            | 4.91e+05 |
# | step               | 7.01e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-13:48:23|
# | current_grad_norm  | 0.0961   |
# | current_param_norm | 376      |
# | grad_norm          | 0.105    |
# | lg_loss_scale      | 19.1     |
# | loss               | 0.0251   |
# | loss_q0            | 0.0848   |
# | loss_q1            | 0.00654  |
# | loss_q2            | 0.0011   |
# | loss_q3            | 0.000234 |
# | mse_audio          | 0.0149   |
# | mse_audio_q0       | 0.0527   |
# | mse_audio_q1       | 0.00186  |
# | mse_audio_q2       | 0.000227 |
# | mse_audio_q3       | 9.3e-05  |
# | mse_video          | 0.0102   |
# | mse_video_q0       | 0.0321   |
# | mse_video_q1       | 0.00468  |
# | mse_video_q2       | 0.000875 |
# | mse_video_q3       | 0.000141 |
# | param_norm         | 376      |
# | samples            | 4.91e+05 |
# | step               | 7.02e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-13:54:09|
# | current_grad_norm  | 0.0744   |
# | current_param_norm | 376      |
# | grad_norm          | 0.114    |
# | lg_loss_scale      | 19.2     |
# | loss               | 0.0199   |
# | loss_q0            | 0.0707   |
# | loss_q1            | 0.00604  |
# | loss_q2            | 0.000973 |
# | loss_q3            | 0.000248 |
# | mse_audio          | 0.0102   |
# | mse_audio_q0       | 0.0381   |
# | mse_audio_q1       | 0.00167  |
# | mse_audio_q2       | 0.000185 |
# | mse_audio_q3       | 8.12e-05 |
# | mse_video          | 0.00967  |
# | mse_video_q0       | 0.0326   |
# | mse_video_q1       | 0.00437  |
# | mse_video_q2       | 0.000788 |
# | mse_video_q3       | 0.000167 |
# | param_norm         | 376      |
# | samples            | 4.92e+05 |
# | step               | 7.03e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-13:59:55|
# | current_grad_norm  | 0.0711   |
# | current_param_norm | 376      |
# | grad_norm          | 0.0989   |
# | lg_loss_scale      | 19.3     |
# | loss               | 0.0197   |
# | loss_q0            | 0.0727   |
# | loss_q1            | 0.00604  |
# | loss_q2            | 0.00107  |
# | loss_q3            | 0.000217 |
# | mse_audio          | 0.0102   |
# | mse_audio_q0       | 0.0396   |
# | mse_audio_q1       | 0.00166  |
# | mse_audio_q2       | 0.000208 |
# | mse_audio_q3       | 6.64e-05 |
# | mse_video          | 0.00945  |
# | mse_video_q0       | 0.033    |
# | mse_video_q1       | 0.00438  |
# | mse_video_q2       | 0.000863 |
# | mse_video_q3       | 0.00015  |
# | param_norm         | 376      |
# | samples            | 4.93e+05 |
# | step               | 7.04e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:05:42|
# | current_grad_norm  | 0.109    |
# | current_param_norm | 377      |
# | grad_norm          | 0.0898   |
# | lg_loss_scale      | 19.4     |
# | loss               | 0.0204   |
# | loss_q0            | 0.0755   |
# | loss_q1            | 0.00606  |
# | loss_q2            | 0.000931 |
# | loss_q3            | 0.000194 |
# | mse_audio          | 0.00951  |
# | mse_audio_q0       | 0.0364   |
# | mse_audio_q1       | 0.00186  |
# | mse_audio_q2       | 0.000219 |
# | mse_audio_q3       | 7.61e-05 |
# | mse_video          | 0.0109   |
# | mse_video_q0       | 0.0391   |
# | mse_video_q1       | 0.0042   |
# | mse_video_q2       | 0.000711 |
# | mse_video_q3       | 0.000118 |
# | param_norm         | 377      |
# | samples            | 4.94e+05 |
# | step               | 7.05e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:11:28|
# | current_grad_norm  | 0.0897   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0888   |
# | lg_loss_scale      | 19.5     |
# | loss               | 0.0183   |
# | loss_q0            | 0.0597   |
# | loss_q1            | 0.00624  |
# | loss_q2            | 0.000886 |
# | loss_q3            | 0.000188 |
# | mse_audio          | 0.0078   |
# | mse_audio_q0       | 0.0265   |
# | mse_audio_q1       | 0.0016   |
# | mse_audio_q2       | 0.000144 |
# | mse_audio_q3       | 6.77e-05 |
# | mse_video          | 0.0106   |
# | mse_video_q0       | 0.0332   |
# | mse_video_q1       | 0.00464  |
# | mse_video_q2       | 0.000743 |
# | mse_video_q3       | 0.00012  |
# | param_norm         | 377      |
# | samples            | 4.94e+05 |
# | step               | 7.06e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:17:15|
# | current_grad_norm  | 0.0601   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0781   |
# | lg_loss_scale      | 19.6     |
# | loss               | 0.0163   |
# | loss_q0            | 0.0602   |
# | loss_q1            | 0.00587  |
# | loss_q2            | 0.000849 |
# | loss_q3            | 0.000175 |
# | mse_audio          | 0.0078   |
# | mse_audio_q0       | 0.0306   |
# | mse_audio_q1       | 0.00152  |
# | mse_audio_q2       | 0.000163 |
# | mse_audio_q3       | 5.47e-05 |
# | mse_video          | 0.00847  |
# | mse_video_q0       | 0.0296   |
# | mse_video_q1       | 0.00435  |
# | mse_video_q2       | 0.000686 |
# | mse_video_q3       | 0.00012  |
# | param_norm         | 377      |
# | samples            | 4.95e+05 |
# | step               | 7.07e+04 |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 18.726000000000887
# ---------------------------------
# |openai-2024-11-18-14:23:01|
# | current_grad_norm  | 0.0573   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0692   |
# | lg_loss_scale      | 19       |
# | loss               | 0.0159   |
# | loss_q0            | 0.0593   |
# | loss_q1            | 0.00536  |
# | loss_q2            | 0.000965 |
# | loss_q3            | 0.000158 |
# | mse_audio          | 0.0079   |
# | mse_audio_q0       | 0.0313   |
# | mse_audio_q1       | 0.00135  |
# | mse_audio_q2       | 0.000156 |
# | mse_audio_q3       | 4.67e-05 |
# | mse_video          | 0.00796  |
# | mse_video_q0       | 0.028    |
# | mse_video_q1       | 0.00401  |
# | mse_video_q2       | 0.000809 |
# | mse_video_q3       | 0.000111 |
# | param_norm         | 377      |
# | samples            | 4.96e+05 |
# | step               | 7.08e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:28:48|
# | current_grad_norm  | 0.0594   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0792   |
# | lg_loss_scale      | 18.8     |
# | loss               | 0.0184   |
# | loss_q0            | 0.0614   |
# | loss_q1            | 0.00572  |
# | loss_q2            | 0.000903 |
# | loss_q3            | 0.000172 |
# | mse_audio          | 0.0105   |
# | mse_audio_q0       | 0.0369   |
# | mse_audio_q1       | 0.00151  |
# | mse_audio_q2       | 0.00022  |
# | mse_audio_q3       | 6.58e-05 |
# | mse_video          | 0.00797  |
# | mse_video_q0       | 0.0245   |
# | mse_video_q1       | 0.0042   |
# | mse_video_q2       | 0.000683 |
# | mse_video_q3       | 0.000106 |
# | param_norm         | 377      |
# | samples            | 4.96e+05 |
# | step               | 7.09e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:34:34|
# | current_grad_norm  | 0.0923   |
# | current_param_norm | 377      |
# | grad_norm          | 0.073    |
# | lg_loss_scale      | 18.9     |
# | loss               | 0.0157   |
# | loss_q0            | 0.0557   |
# | loss_q1            | 0.00615  |
# | loss_q2            | 0.00102  |
# | loss_q3            | 0.000161 |
# | mse_audio          | 0.00821  |
# | mse_audio_q0       | 0.0311   |
# | mse_audio_q1       | 0.00167  |
# | mse_audio_q2       | 0.000253 |
# | mse_audio_q3       | 5.38e-05 |
# | mse_video          | 0.00748  |
# | mse_video_q0       | 0.0246   |
# | mse_video_q1       | 0.00449  |
# | mse_video_q2       | 0.000765 |
# | mse_video_q3       | 0.000108 |
# | param_norm         | 377      |
# | samples            | 4.97e+05 |
# | step               | 7.1e+04  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:40:20|
# | current_grad_norm  | 0.0794   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0822   |
# | lg_loss_scale      | 19       |
# | loss               | 0.0211   |
# | loss_q0            | 0.0764   |
# | loss_q1            | 0.00578  |
# | loss_q2            | 0.00094  |
# | loss_q3            | 0.000162 |
# | mse_audio          | 0.0117   |
# | mse_audio_q0       | 0.0441   |
# | mse_audio_q1       | 0.00171  |
# | mse_audio_q2       | 0.000151 |
# | mse_audio_q3       | 5.92e-05 |
# | mse_video          | 0.0094   |
# | mse_video_q0       | 0.0324   |
# | mse_video_q1       | 0.00407  |
# | mse_video_q2       | 0.000789 |
# | mse_video_q3       | 0.000103 |
# | param_norm         | 377      |
# | samples            | 4.98e+05 |
# | step               | 7.11e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:46:08|
# | current_grad_norm  | 0.0369   |
# | current_param_norm | 377      |
# | grad_norm          | 0.079    |
# | lg_loss_scale      | 19.1     |
# | loss               | 0.0161   |
# | loss_q0            | 0.0598   |
# | loss_q1            | 0.00627  |
# | loss_q2            | 0.000872 |
# | loss_q3            | 0.000209 |
# | mse_audio          | 0.00759  |
# | mse_audio_q0       | 0.03     |
# | mse_audio_q1       | 0.00142  |
# | mse_audio_q2       | 0.000138 |
# | mse_audio_q3       | 5.8e-05  |
# | mse_video          | 0.00851  |
# | mse_video_q0       | 0.0298   |
# | mse_video_q1       | 0.00485  |
# | mse_video_q2       | 0.000734 |
# | mse_video_q3       | 0.000151 |
# | param_norm         | 377      |
# | samples            | 4.98e+05 |
# | step               | 7.12e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:51:55|
# | current_grad_norm  | 0.0516   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0715   |
# | lg_loss_scale      | 19.2     |
# | loss               | 0.0149   |
# | loss_q0            | 0.0501   |
# | loss_q1            | 0.00664  |
# | loss_q2            | 0.000872 |
# | loss_q3            | 0.000162 |
# | mse_audio          | 0.00632  |
# | mse_audio_q0       | 0.022    |
# | mse_audio_q1       | 0.00223  |
# | mse_audio_q2       | 0.000165 |
# | mse_audio_q3       | 5.24e-05 |
# | mse_video          | 0.00861  |
# | mse_video_q0       | 0.0281   |
# | mse_video_q1       | 0.0044   |
# | mse_video_q2       | 0.000708 |
# | mse_video_q3       | 0.000109 |
# | param_norm         | 377      |
# | samples            | 4.99e+05 |
# | step               | 7.13e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-14:57:42|
# | current_grad_norm  | 0.0526   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0727   |
# | lg_loss_scale      | 19.3     |
# | loss               | 0.0195   |
# | loss_q0            | 0.0688   |
# | loss_q1            | 0.00518  |
# | loss_q2            | 0.000858 |
# | loss_q3            | 0.000153 |
# | mse_audio          | 0.00975  |
# | mse_audio_q0       | 0.0357   |
# | mse_audio_q1       | 0.00143  |
# | mse_audio_q2       | 0.000177 |
# | mse_audio_q3       | 5.2e-05  |
# | mse_video          | 0.00977  |
# | mse_video_q0       | 0.0331   |
# | mse_video_q1       | 0.00374  |
# | mse_video_q2       | 0.000681 |
# | mse_video_q3       | 0.000101 |
# | param_norm         | 377      |
# | samples            | 5e+05    |
# | step               | 7.14e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:03:28|
# | current_grad_norm  | 0.0803   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0693   |
# | lg_loss_scale      | 19.4     |
# | loss               | 0.0174   |
# | loss_q0            | 0.0607   |
# | loss_q1            | 0.00548  |
# | loss_q2            | 0.000847 |
# | loss_q3            | 0.000161 |
# | mse_audio          | 0.00922  |
# | mse_audio_q0       | 0.0335   |
# | mse_audio_q1       | 0.00176  |
# | mse_audio_q2       | 0.000212 |
# | mse_audio_q3       | 5.8e-05  |
# | mse_video          | 0.00819  |
# | mse_video_q0       | 0.0272   |
# | mse_video_q1       | 0.00372  |
# | mse_video_q2       | 0.000634 |
# | mse_video_q3       | 0.000103 |
# | param_norm         | 377      |
# | samples            | 5.01e+05 |
# | step               | 7.15e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:09:14|
# | current_grad_norm  | 0.0539   |
# | current_param_norm | 377      |
# | grad_norm          | 0.078    |
# | lg_loss_scale      | 19.5     |
# | loss               | 0.0194   |
# | loss_q0            | 0.0645   |
# | loss_q1            | 0.0055   |
# | loss_q2            | 0.000852 |
# | loss_q3            | 0.000177 |
# | mse_audio          | 0.00989  |
# | mse_audio_q0       | 0.0343   |
# | mse_audio_q1       | 0.0014   |
# | mse_audio_q2       | 0.000153 |
# | mse_audio_q3       | 6.14e-05 |
# | mse_video          | 0.0095   |
# | mse_video_q0       | 0.0303   |
# | mse_video_q1       | 0.0041   |
# | mse_video_q2       | 0.0007   |
# | mse_video_q3       | 0.000116 |
# | param_norm         | 377      |
# | samples            | 5.01e+05 |
# | step               | 7.16e+04 |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 18.610000000001968
# ---------------------------------
# |openai-2024-11-18-15:15:00|
# | current_grad_norm  | 0.0624   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0869   |
# | lg_loss_scale      | 18.8     |
# | loss               | 0.0192   |
# | loss_q0            | 0.0817   |
# | loss_q1            | 0.00551  |
# | loss_q2            | 0.000978 |
# | loss_q3            | 0.000193 |
# | mse_audio          | 0.0109   |
# | mse_audio_q0       | 0.0491   |
# | mse_audio_q1       | 0.00134  |
# | mse_audio_q2       | 0.000176 |
# | mse_audio_q3       | 5.6e-05  |
# | mse_video          | 0.00829  |
# | mse_video_q0       | 0.0326   |
# | mse_video_q1       | 0.00417  |
# | mse_video_q2       | 0.000802 |
# | mse_video_q3       | 0.000137 |
# | param_norm         | 377      |
# | samples            | 5.02e+05 |
# | step               | 7.17e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:20:45|
# | current_grad_norm  | 0.0502   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0808   |
# | lg_loss_scale      | 18.7     |
# | loss               | 0.0148   |
# | loss_q0            | 0.0526   |
# | loss_q1            | 0.00514  |
# | loss_q2            | 0.000794 |
# | loss_q3            | 0.00017  |
# | mse_audio          | 0.00675  |
# | mse_audio_q0       | 0.0253   |
# | mse_audio_q1       | 0.00125  |
# | mse_audio_q2       | 0.000155 |
# | mse_audio_q3       | 4.89e-05 |
# | mse_video          | 0.00807  |
# | mse_video_q0       | 0.0273   |
# | mse_video_q1       | 0.00389  |
# | mse_video_q2       | 0.000639 |
# | mse_video_q3       | 0.000121 |
# | param_norm         | 377      |
# | samples            | 5.03e+05 |
# | step               | 7.18e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:26:32|
# | current_grad_norm  | 0.113    |
# | current_param_norm | 377      |
# | grad_norm          | 0.0793   |
# | lg_loss_scale      | 18.8     |
# | loss               | 0.0186   |
# | loss_q0            | 0.0664   |
# | loss_q1            | 0.00553  |
# | loss_q2            | 0.000811 |
# | loss_q3            | 0.000159 |
# | mse_audio          | 0.00979  |
# | mse_audio_q0       | 0.0365   |
# | mse_audio_q1       | 0.00152  |
# | mse_audio_q2       | 0.000178 |
# | mse_audio_q3       | 5.67e-05 |
# | mse_video          | 0.00883  |
# | mse_video_q0       | 0.0299   |
# | mse_video_q1       | 0.00401  |
# | mse_video_q2       | 0.000633 |
# | mse_video_q3       | 0.000102 |
# | param_norm         | 377      |
# | samples            | 5.03e+05 |
# | step               | 7.19e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:32:17|
# | current_grad_norm  | 0.0479   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0917   |
# | lg_loss_scale      | 18.9     |
# | loss               | 0.0195   |
# | loss_q0            | 0.0672   |
# | loss_q1            | 0.00493  |
# | loss_q2            | 0.000882 |
# | loss_q3            | 0.000195 |
# | mse_audio          | 0.0116   |
# | mse_audio_q0       | 0.0417   |
# | mse_audio_q1       | 0.0014   |
# | mse_audio_q2       | 0.000186 |
# | mse_audio_q3       | 7.61e-05 |
# | mse_video          | 0.00791  |
# | mse_video_q0       | 0.0255   |
# | mse_video_q1       | 0.00353  |
# | mse_video_q2       | 0.000696 |
# | mse_video_q3       | 0.000119 |
# | param_norm         | 377      |
# | samples            | 5.04e+05 |
# | step               | 7.2e+04  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:38:04|
# | current_grad_norm  | 0.0982   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0886   |
# | lg_loss_scale      | 19       |
# | loss               | 0.0189   |
# | loss_q0            | 0.0648   |
# | loss_q1            | 0.00525  |
# | loss_q2            | 0.000973 |
# | loss_q3            | 0.000186 |
# | mse_audio          | 0.00819  |
# | mse_audio_q0       | 0.0292   |
# | mse_audio_q1       | 0.00132  |
# | mse_audio_q2       | 0.000198 |
# | mse_audio_q3       | 6.32e-05 |
# | mse_video          | 0.0107   |
# | mse_video_q0       | 0.0356   |
# | mse_video_q1       | 0.00394  |
# | mse_video_q2       | 0.000775 |
# | mse_video_q3       | 0.000123 |
# | param_norm         | 377      |
# | samples            | 5.05e+05 |
# | step               | 7.21e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:43:50|
# | current_grad_norm  | 0.0613   |
# | current_param_norm | 377      |
# | grad_norm          | 0.077    |
# | lg_loss_scale      | 19.1     |
# | loss               | 0.0185   |
# | loss_q0            | 0.0726   |
# | loss_q1            | 0.00566  |
# | loss_q2            | 0.000895 |
# | loss_q3            | 0.000159 |
# | mse_audio          | 0.0103   |
# | mse_audio_q0       | 0.043    |
# | mse_audio_q1       | 0.00143  |
# | mse_audio_q2       | 0.000161 |
# | mse_audio_q3       | 5.17e-05 |
# | mse_video          | 0.00816  |
# | mse_video_q0       | 0.0296   |
# | mse_video_q1       | 0.00423  |
# | mse_video_q2       | 0.000734 |
# | mse_video_q3       | 0.000107 |
# | param_norm         | 377      |
# | samples            | 5.05e+05 |
# | step               | 7.22e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:49:36|
# | current_grad_norm  | 0.0908   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0773   |
# | lg_loss_scale      | 19.2     |
# | loss               | 0.0166   |
# | loss_q0            | 0.0584   |
# | loss_q1            | 0.006    |
# | loss_q2            | 0.000952 |
# | loss_q3            | 0.000167 |
# | mse_audio          | 0.00886  |
# | mse_audio_q0       | 0.0327   |
# | mse_audio_q1       | 0.00185  |
# | mse_audio_q2       | 0.000163 |
# | mse_audio_q3       | 5.71e-05 |
# | mse_video          | 0.00776  |
# | mse_video_q0       | 0.0258   |
# | mse_video_q1       | 0.00415  |
# | mse_video_q2       | 0.000789 |
# | mse_video_q3       | 0.00011  |
# | param_norm         | 377      |
# | samples            | 5.06e+05 |
# | step               | 7.23e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-15:55:21|
# | current_grad_norm  | 0.0789   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0791   |
# | lg_loss_scale      | 19.3     |
# | loss               | 0.0168   |
# | loss_q0            | 0.0566   |
# | loss_q1            | 0.00567  |
# | loss_q2            | 0.000895 |
# | loss_q3            | 0.000164 |
# | mse_audio          | 0.00907  |
# | mse_audio_q0       | 0.0321   |
# | mse_audio_q1       | 0.00179  |
# | mse_audio_q2       | 0.000177 |
# | mse_audio_q3       | 6.08e-05 |
# | mse_video          | 0.00772  |
# | mse_video_q0       | 0.0245   |
# | mse_video_q1       | 0.00388  |
# | mse_video_q2       | 0.000718 |
# | mse_video_q3       | 0.000104 |
# | param_norm         | 377      |
# | samples            | 5.07e+05 |
# | step               | 7.24e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:01:07|
# | current_grad_norm  | 0.0601   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0675   |
# | lg_loss_scale      | 19.4     |
# | loss               | 0.0135   |
# | loss_q0            | 0.0545   |
# | loss_q1            | 0.00564  |
# | loss_q2            | 0.000794 |
# | loss_q3            | 0.000152 |
# | mse_audio          | 0.00616  |
# | mse_audio_q0       | 0.0266   |
# | mse_audio_q1       | 0.00143  |
# | mse_audio_q2       | 0.000176 |
# | mse_audio_q3       | 4.45e-05 |
# | mse_video          | 0.0073   |
# | mse_video_q0       | 0.0279   |
# | mse_video_q1       | 0.00421  |
# | mse_video_q2       | 0.000618 |
# | mse_video_q3       | 0.000108 |
# | param_norm         | 377      |
# | samples            | 5.08e+05 |
# | step               | 7.25e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:06:53|
# | current_grad_norm  | 0.0809   |
# | current_param_norm | 377      |
# | grad_norm          | 0.073    |
# | lg_loss_scale      | 19.5     |
# | loss               | 0.0198   |
# | loss_q0            | 0.066    |
# | loss_q1            | 0.00578  |
# | loss_q2            | 0.00092  |
# | loss_q3            | 0.000161 |
# | mse_audio          | 0.011    |
# | mse_audio_q0       | 0.0389   |
# | mse_audio_q1       | 0.0014   |
# | mse_audio_q2       | 0.000164 |
# | mse_audio_q3       | 5.52e-05 |
# | mse_video          | 0.00877  |
# | mse_video_q0       | 0.0272   |
# | mse_video_q1       | 0.00438  |
# | mse_video_q2       | 0.000756 |
# | mse_video_q3       | 0.000106 |
# | param_norm         | 377      |
# | samples            | 5.08e+05 |
# | step               | 7.26e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:12:40|
# | current_grad_norm  | 0.05     |
# | current_param_norm | 377      |
# | grad_norm          | 0.0772   |
# | lg_loss_scale      | 19.6     |
# | loss               | 0.0176   |
# | loss_q0            | 0.0672   |
# | loss_q1            | 0.00536  |
# | loss_q2            | 0.000868 |
# | loss_q3            | 0.000169 |
# | mse_audio          | 0.0088   |
# | mse_audio_q0       | 0.0354   |
# | mse_audio_q1       | 0.00138  |
# | mse_audio_q2       | 0.000161 |
# | mse_audio_q3       | 4.89e-05 |
# | mse_video          | 0.00876  |
# | mse_video_q0       | 0.0318   |
# | mse_video_q1       | 0.00398  |
# | mse_video_q2       | 0.000707 |
# | mse_video_q3       | 0.00012  |
# | param_norm         | 377      |
# | samples            | 5.09e+05 |
# | step               | 7.27e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:18:27|
# | current_grad_norm  | 0.112    |
# | current_param_norm | 377      |
# | grad_norm          | 0.0691   |
# | lg_loss_scale      | 19.7     |
# | loss               | 0.0149   |
# | loss_q0            | 0.0628   |
# | loss_q1            | 0.00608  |
# | loss_q2            | 0.000981 |
# | loss_q3            | 0.00016  |
# | mse_audio          | 0.0062   |
# | mse_audio_q0       | 0.0278   |
# | mse_audio_q1       | 0.00144  |
# | mse_audio_q2       | 0.000143 |
# | mse_audio_q3       | 4.81e-05 |
# | mse_video          | 0.00872  |
# | mse_video_q0       | 0.0351   |
# | mse_video_q1       | 0.00463  |
# | mse_video_q2       | 0.000838 |
# | mse_video_q3       | 0.000112 |
# | param_norm         | 377      |
# | samples            | 5.1e+05  |
# | step               | 7.28e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:24:14|
# | current_grad_norm  | 0.0585   |
# | current_param_norm | 377      |
# | grad_norm          | 0.0864   |
# | lg_loss_scale      | 19.8     |
# | loss               | 0.0171   |
# | loss_q0            | 0.0603   |
# | loss_q1            | 0.0053   |
# | loss_q2            | 0.00086  |
# | loss_q3            | 0.000211 |
# | mse_audio          | 0.00807  |
# | mse_audio_q0       | 0.0298   |
# | mse_audio_q1       | 0.00125  |
# | mse_audio_q2       | 0.000149 |
# | mse_audio_q3       | 5.3e-05  |
# | mse_video          | 0.00903  |
# | mse_video_q0       | 0.0305   |
# | mse_video_q1       | 0.00406  |
# | mse_video_q2       | 0.000711 |
# | mse_video_q3       | 0.000158 |
# | param_norm         | 377      |
# | samples            | 5.1e+05  |
# | step               | 7.29e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:29:59|
# | current_grad_norm  | 0.214    |
# | current_param_norm | 378      |
# | grad_norm          | 0.118    |
# | lg_loss_scale      | 19.9     |
# | loss               | 0.0217   |
# | loss_q0            | 0.0702   |
# | loss_q1            | 0.00545  |
# | loss_q2            | 0.000841 |
# | loss_q3            | 0.000227 |
# | mse_audio          | 0.011    |
# | mse_audio_q0       | 0.0369   |
# | mse_audio_q1       | 0.00154  |
# | mse_audio_q2       | 0.000176 |
# | mse_audio_q3       | 8.18e-05 |
# | mse_video          | 0.0107   |
# | mse_video_q0       | 0.0333   |
# | mse_video_q1       | 0.00391  |
# | mse_video_q2       | 0.000665 |
# | mse_video_q3       | 0.000145 |
# | param_norm         | 377      |
# | samples            | 5.11e+05 |
# | step               | 7.3e+04  |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 19.033000000003707
# ---------------------------------
# |openai-2024-11-18-16:35:47|
# | current_grad_norm  | 0.0557   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0722   |
# | lg_loss_scale      | 19.4     |
# | loss               | 0.017    |
# | loss_q0            | 0.0605   |
# | loss_q1            | 0.00611  |
# | loss_q2            | 0.000917 |
# | loss_q3            | 0.000163 |
# | mse_audio          | 0.00933  |
# | mse_audio_q0       | 0.0359   |
# | mse_audio_q1       | 0.0013   |
# | mse_audio_q2       | 0.000173 |
# | mse_audio_q3       | 6.28e-05 |
# | mse_video          | 0.00764  |
# | mse_video_q0       | 0.0247   |
# | mse_video_q1       | 0.00481  |
# | mse_video_q2       | 0.000744 |
# | mse_video_q3       | 0.0001   |
# | param_norm         | 378      |
# | samples            | 5.12e+05 |
# | step               | 7.31e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:41:33|
# | current_grad_norm  | 0.109    |
# | current_param_norm | 378      |
# | grad_norm          | 0.0977   |
# | lg_loss_scale      | 19.1     |
# | loss               | 0.0207   |
# | loss_q0            | 0.0744   |
# | loss_q1            | 0.00525  |
# | loss_q2            | 0.000898 |
# | loss_q3            | 0.000182 |
# | mse_audio          | 0.0122   |
# | mse_audio_q0       | 0.0454   |
# | mse_audio_q1       | 0.00185  |
# | mse_audio_q2       | 0.000192 |
# | mse_audio_q3       | 7e-05    |
# | mse_video          | 0.0085   |
# | mse_video_q0       | 0.029    |
# | mse_video_q1       | 0.00341  |
# | mse_video_q2       | 0.000706 |
# | mse_video_q3       | 0.000112 |
# | param_norm         | 378      |
# | samples            | 5.12e+05 |
# | step               | 7.32e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:47:20|
# | current_grad_norm  | 0.0795   |
# | current_param_norm | 378      |
# | grad_norm          | 0.078    |
# | lg_loss_scale      | 19.2     |
# | loss               | 0.0171   |
# | loss_q0            | 0.0572   |
# | loss_q1            | 0.0056   |
# | loss_q2            | 0.000826 |
# | loss_q3            | 0.000179 |
# | mse_audio          | 0.00819  |
# | mse_audio_q0       | 0.0288   |
# | mse_audio_q1       | 0.00147  |
# | mse_audio_q2       | 0.000152 |
# | mse_audio_q3       | 6.61e-05 |
# | mse_video          | 0.0089   |
# | mse_video_q0       | 0.0284   |
# | mse_video_q1       | 0.00413  |
# | mse_video_q2       | 0.000674 |
# | mse_video_q3       | 0.000112 |
# | param_norm         | 378      |
# | samples            | 5.13e+05 |
# | step               | 7.33e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:53:06|
# | current_grad_norm  | 0.0453   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0812   |
# | lg_loss_scale      | 19.3     |
# | loss               | 0.0218   |
# | loss_q0            | 0.0791   |
# | loss_q1            | 0.00571  |
# | loss_q2            | 0.000803 |
# | loss_q3            | 0.000154 |
# | mse_audio          | 0.0133   |
# | mse_audio_q0       | 0.051    |
# | mse_audio_q1       | 0.00143  |
# | mse_audio_q2       | 0.000168 |
# | mse_audio_q3       | 5.4e-05  |
# | mse_video          | 0.00845  |
# | mse_video_q0       | 0.0281   |
# | mse_video_q1       | 0.00427  |
# | mse_video_q2       | 0.000635 |
# | mse_video_q3       | 0.0001   |
# | param_norm         | 378      |
# | samples            | 5.14e+05 |
# | step               | 7.34e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-16:58:52|
# | current_grad_norm  | 0.0954   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0705   |
# | lg_loss_scale      | 19.4     |
# | loss               | 0.0138   |
# | loss_q0            | 0.0545   |
# | loss_q1            | 0.00535  |
# | loss_q2            | 0.000857 |
# | loss_q3            | 0.000164 |
# | mse_audio          | 0.00799  |
# | mse_audio_q0       | 0.0338   |
# | mse_audio_q1       | 0.00151  |
# | mse_audio_q2       | 0.000167 |
# | mse_audio_q3       | 6.07e-05 |
# | mse_video          | 0.00583  |
# | mse_video_q0       | 0.0207   |
# | mse_video_q1       | 0.00384  |
# | mse_video_q2       | 0.000689 |
# | mse_video_q3       | 0.000104 |
# | param_norm         | 378      |
# | samples            | 5.15e+05 |
# | step               | 7.35e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:04:37|
# | current_grad_norm  | 0.0636   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0829   |
# | lg_loss_scale      | 19.5     |
# | loss               | 0.0174   |
# | loss_q0            | 0.061    |
# | loss_q1            | 0.00584  |
# | loss_q2            | 0.000817 |
# | loss_q3            | 0.000184 |
# | mse_audio          | 0.00893  |
# | mse_audio_q0       | 0.0325   |
# | mse_audio_q1       | 0.00192  |
# | mse_audio_q2       | 0.000144 |
# | mse_audio_q3       | 5.58e-05 |
# | mse_video          | 0.00852  |
# | mse_video_q0       | 0.0285   |
# | mse_video_q1       | 0.00392  |
# | mse_video_q2       | 0.000673 |
# | mse_video_q3       | 0.000128 |
# | param_norm         | 378      |
# | samples            | 5.15e+05 |
# | step               | 7.36e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:10:24|
# | current_grad_norm  | 0.0663   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0642   |
# | lg_loss_scale      | 19.6     |
# | loss               | 0.0152   |
# | loss_q0            | 0.0588   |
# | loss_q1            | 0.00506  |
# | loss_q2            | 0.000879 |
# | loss_q3            | 0.000157 |
# | mse_audio          | 0.0073   |
# | mse_audio_q0       | 0.0297   |
# | mse_audio_q1       | 0.00133  |
# | mse_audio_q2       | 0.000179 |
# | mse_audio_q3       | 4.88e-05 |
# | mse_video          | 0.00786  |
# | mse_video_q0       | 0.0291   |
# | mse_video_q1       | 0.00372  |
# | mse_video_q2       | 0.0007   |
# | mse_video_q3       | 0.000108 |
# | param_norm         | 378      |
# | samples            | 5.16e+05 |
# | step               | 7.37e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:16:10|
# | current_grad_norm  | 0.0566   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0724   |
# | lg_loss_scale      | 19.7     |
# | loss               | 0.0148   |
# | loss_q0            | 0.0513   |
# | loss_q1            | 0.00488  |
# | loss_q2            | 0.000785 |
# | loss_q3            | 0.000159 |
# | mse_audio          | 0.00626  |
# | mse_audio_q0       | 0.0227   |
# | mse_audio_q1       | 0.00135  |
# | mse_audio_q2       | 0.00015  |
# | mse_audio_q3       | 4.81e-05 |
# | mse_video          | 0.00853  |
# | mse_video_q0       | 0.0286   |
# | mse_video_q1       | 0.00353  |
# | mse_video_q2       | 0.000635 |
# | mse_video_q3       | 0.000111 |
# | param_norm         | 378      |
# | samples            | 5.17e+05 |
# | step               | 7.38e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:21:58|
# | current_grad_norm  | 0.0877   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0826   |
# | lg_loss_scale      | 19.8     |
# | loss               | 0.0162   |
# | loss_q0            | 0.0592   |
# | loss_q1            | 0.00515  |
# | loss_q2            | 0.000818 |
# | loss_q3            | 0.000177 |
# | mse_audio          | 0.00855  |
# | mse_audio_q0       | 0.0333   |
# | mse_audio_q1       | 0.00132  |
# | mse_audio_q2       | 0.000168 |
# | mse_audio_q3       | 5.18e-05 |
# | mse_video          | 0.00761  |
# | mse_video_q0       | 0.026    |
# | mse_video_q1       | 0.00382  |
# | mse_video_q2       | 0.000649 |
# | mse_video_q3       | 0.000125 |
# | param_norm         | 378      |
# | samples            | 5.17e+05 |
# | step               | 7.39e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:27:43|
# | current_grad_norm  | 0.0623   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0707   |
# | lg_loss_scale      | 19.9     |
# | loss               | 0.0144   |
# | loss_q0            | 0.058    |
# | loss_q1            | 0.00495  |
# | loss_q2            | 0.000855 |
# | loss_q3            | 0.000166 |
# | mse_audio          | 0.00725  |
# | mse_audio_q0       | 0.0308   |
# | mse_audio_q1       | 0.0013   |
# | mse_audio_q2       | 0.000205 |
# | mse_audio_q3       | 5.4e-05  |
# | mse_video          | 0.00716  |
# | mse_video_q0       | 0.0272   |
# | mse_video_q1       | 0.00365  |
# | mse_video_q2       | 0.00065  |
# | mse_video_q3       | 0.000112 |
# | param_norm         | 378      |
# | samples            | 5.18e+05 |
# | step               | 7.4e+04  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:33:29|
# | current_grad_norm  | 0.0759   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0698   |
# | lg_loss_scale      | 20       |
# | loss               | 0.0173   |
# | loss_q0            | 0.06     |
# | loss_q1            | 0.00538  |
# | loss_q2            | 0.000807 |
# | loss_q3            | 0.000156 |
# | mse_audio          | 0.00915  |
# | mse_audio_q0       | 0.0332   |
# | mse_audio_q1       | 0.00156  |
# | mse_audio_q2       | 0.000133 |
# | mse_audio_q3       | 5.37e-05 |
# | mse_video          | 0.00815  |
# | mse_video_q0       | 0.0268   |
# | mse_video_q1       | 0.00381  |
# | mse_video_q2       | 0.000673 |
# | mse_video_q3       | 0.000103 |
# | param_norm         | 378      |
# | samples            | 5.19e+05 |
# | step               | 7.41e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:39:17|
# | current_grad_norm  | 0.063    |
# | current_param_norm | 378      |
# | grad_norm          | 0.0694   |
# | lg_loss_scale      | 20.1     |
# | loss               | 0.0174   |
# | loss_q0            | 0.0565   |
# | loss_q1            | 0.00611  |
# | loss_q2            | 0.000736 |
# | loss_q3            | 0.000162 |
# | mse_audio          | 0.00903  |
# | mse_audio_q0       | 0.0309   |
# | mse_audio_q1       | 0.00157  |
# | mse_audio_q2       | 0.00015  |
# | mse_audio_q3       | 4.79e-05 |
# | mse_video          | 0.00841  |
# | mse_video_q0       | 0.0256   |
# | mse_video_q1       | 0.00454  |
# | mse_video_q2       | 0.000586 |
# | mse_video_q3       | 0.000114 |
# | param_norm         | 378      |
# | samples            | 5.19e+05 |
# | step               | 7.42e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:45:04|
# | current_grad_norm  | 0.0836   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0782   |
# | lg_loss_scale      | 20.2     |
# | loss               | 0.0174   |
# | loss_q0            | 0.0553   |
# | loss_q1            | 0.00532  |
# | loss_q2            | 0.000857 |
# | loss_q3            | 0.000171 |
# | mse_audio          | 0.00791  |
# | mse_audio_q0       | 0.0261   |
# | mse_audio_q1       | 0.0015   |
# | mse_audio_q2       | 0.000162 |
# | mse_audio_q3       | 5.02e-05 |
# | mse_video          | 0.00948  |
# | mse_video_q0       | 0.0291   |
# | mse_video_q1       | 0.00382  |
# | mse_video_q2       | 0.000695 |
# | mse_video_q3       | 0.00012  |
# | param_norm         | 378      |
# | samples            | 5.2e+05  |
# | step               | 7.43e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-17:50:50|
# | current_grad_norm  | 0.099    |
# | current_param_norm | 378      |
# | grad_norm          | 0.0775   |
# | lg_loss_scale      | 20.3     |
# | loss               | 0.0193   |
# | loss_q0            | 0.0736   |
# | loss_q1            | 0.00549  |
# | loss_q2            | 0.000808 |
# | loss_q3            | 0.000166 |
# | mse_audio          | 0.0105   |
# | mse_audio_q0       | 0.0423   |
# | mse_audio_q1       | 0.00132  |
# | mse_audio_q2       | 0.000176 |
# | mse_audio_q3       | 6.35e-05 |
# | mse_video          | 0.00874  |
# | mse_video_q0       | 0.0314   |
# | mse_video_q1       | 0.00417  |
# | mse_video_q2       | 0.000632 |
# | mse_video_q3       | 0.000103 |
# | param_norm         | 378      |
# | samples            | 5.21e+05 |
# | step               | 7.44e+04 |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 19.406000000005385
# ---------------------------------
# |openai-2024-11-18-17:56:37|
# | current_grad_norm  | 0.188    |
# | current_param_norm | 378      |
# | grad_norm          | 0.0756   |
# | lg_loss_scale      | 19.6     |
# | loss               | 0.0213   |
# | loss_q0            | 0.0796   |
# | loss_q1            | 0.00515  |
# | loss_q2            | 0.00091  |
# | loss_q3            | 0.000167 |
# | mse_audio          | 0.0123   |
# | mse_audio_q0       | 0.0482   |
# | mse_audio_q1       | 0.00105  |
# | mse_audio_q2       | 0.000244 |
# | mse_audio_q3       | 5.46e-05 |
# | mse_video          | 0.00901  |
# | mse_video_q0       | 0.0313   |
# | mse_video_q1       | 0.0041   |
# | mse_video_q2       | 0.000666 |
# | mse_video_q3       | 0.000113 |
# | param_norm         | 378      |
# | samples            | 5.22e+05 |
# | step               | 7.45e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-18:02:24|
# | current_grad_norm  | 0.047    |
# | current_param_norm | 378      |
# | grad_norm          | 0.073    |
# | lg_loss_scale      | 19.5     |
# | loss               | 0.0176   |
# | loss_q0            | 0.0676   |
# | loss_q1            | 0.00574  |
# | loss_q2            | 0.000835 |
# | loss_q3            | 0.000168 |
# | mse_audio          | 0.00812  |
# | mse_audio_q0       | 0.0327   |
# | mse_audio_q1       | 0.00156  |
# | mse_audio_q2       | 0.000152 |
# | mse_audio_q3       | 5.19e-05 |
# | mse_video          | 0.00945  |
# | mse_video_q0       | 0.0349   |
# | mse_video_q1       | 0.00418  |
# | mse_video_q2       | 0.000683 |
# | mse_video_q3       | 0.000116 |
# | param_norm         | 378      |
# | samples            | 5.22e+05 |
# | step               | 7.46e+04 |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 18.611000000005635
# ---------------------------------
# |openai-2024-11-18-18:08:10|
# | current_grad_norm  | 0.0417   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0771   |
# | lg_loss_scale      | 18.8     |
# | loss               | 0.0174   |
# | loss_q0            | 0.0683   |
# | loss_q1            | 0.00501  |
# | loss_q2            | 0.000869 |
# | loss_q3            | 0.000177 |
# | mse_audio          | 0.0085   |
# | mse_audio_q0       | 0.0347   |
# | mse_audio_q1       | 0.00133  |
# | mse_audio_q2       | 0.000161 |
# | mse_audio_q3       | 5.63e-05 |
# | mse_video          | 0.00895  |
# | mse_video_q0       | 0.0336   |
# | mse_video_q1       | 0.00368  |
# | mse_video_q2       | 0.000708 |
# | mse_video_q3       | 0.000121 |
# | param_norm         | 378      |
# | samples            | 5.23e+05 |
# | step               | 7.47e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-18:13:56|
# | current_grad_norm  | 0.0423   |
# | current_param_norm | 378      |
# | grad_norm          | 0.0832   |
# | lg_loss_scale      | 18.7     |
# | loss               | 0.0194   |
# | loss_q0            | 0.0638   |
# | loss_q1            | 0.00556  |
# | loss_q2            | 0.000744 |
# | loss_q3            | 0.000163 |
# | mse_audio          | 0.00997  |
# | mse_audio_q0       | 0.0342   |
# | mse_audio_q1       | 0.00127  |
# | mse_audio_q2       | 0.000145 |
# | mse_audio_q3       | 6.48e-05 |
# | mse_video          | 0.00944  |
# | mse_video_q0       | 0.0296   |
# | mse_video_q1       | 0.00429  |
# | mse_video_q2       | 0.000599 |
# | mse_video_q3       | 9.86e-05 |
# | param_norm         | 378      |
# | samples            | 5.24e+05 |
# | step               | 7.48e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-18:19:43|
# | current_grad_norm  | 0.0416   |
# | current_param_norm | 379      |
# | grad_norm          | 0.0721   |
# | lg_loss_scale      | 18.8     |
# | loss               | 0.0155   |
# | loss_q0            | 0.0608   |
# | loss_q1            | 0.00567  |
# | loss_q2            | 0.00079  |
# | loss_q3            | 0.00016  |
# | mse_audio          | 0.00775  |
# | mse_audio_q0       | 0.0319   |
# | mse_audio_q1       | 0.00181  |
# | mse_audio_q2       | 0.000165 |
# | mse_audio_q3       | 5.04e-05 |
# | mse_video          | 0.00773  |
# | mse_video_q0       | 0.0288   |
# | mse_video_q1       | 0.00387  |
# | mse_video_q2       | 0.000624 |
# | mse_video_q3       | 0.00011  |
# | param_norm         | 379      |
# | samples            | 5.24e+05 |
# | step               | 7.49e+04 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-18-18:25:28|
# | current_grad_norm  | 0.0638   |
# | current_param_norm | 379      |
# | grad_norm          | 0.0713   |
# | lg_loss_scale      | 18.9     |
# | loss               | 0.0157   |
# | loss_q0            | 0.0612   |
# | loss_q1            | 0.00519  |
# | loss_q2            | 0.000781 |
# | loss_q3            | 0.00016  |
# | mse_audio          | 0.00866  |
# | mse_audio_q0       | 0.0358   |
# | mse_audio_q1       | 0.00143  |
# | mse_audio_q2       | 0.000159 |
# | mse_audio_q3       | 5.95e-05 |
# | mse_video          | 0.00702  |
# | mse_video_q0       | 0.0255   |
# | mse_video_q1       | 0.00376  |
# | mse_video_q2       | 0.000622 |
# | mse_video_q3       | 0.0001   |
# | param_norm         | 379      |
# | samples            | 5.25e+05 |
# | step               | 7.5e+04  |
# ---------------------------------
# saving model 0...
# saving model 0.9999...
# create samples...
# 100%|██████████| 1000/1000 [26:44<00:00,  1.60s/it]
# 7 has sampled
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_0.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_0TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_0.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_0.mp4
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_1.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_1TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_1.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_1.mp4
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_2.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_2TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_2.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_2.mp4
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_3.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_3TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_3.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_3.mp4
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_4.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_4TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_4.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_4.mp4
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_5.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_5TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_5.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_5.mp4
# Moviepy - Building video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_6.mp4.
# MoviePy - Writing audio in ddpm_samples_steps5000_6TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_6.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/ddpm_samples_steps5000_6.mp4
# created 7 samples
# ---------------------------------
# |openai-2024-11-18-18:58:05|
# | current_grad_norm  | 0.0411   |
# | current_param_norm | 379      |
# | grad_norm          | 0.0756   |
# | lg_loss_scale      | 19       |
# | loss               | 0.016    |
# | loss_q0            | 0.0599   |
# | loss_q1            | 0.00524  |
# | loss_q2            | 0.000811 |
# | loss_q3            | 0.000162 |
# | mse_audio          | 0.00789  |
# | mse_audio_q0       | 0.0312   |
# | mse_audio_q1       | 0.00129  |
# | mse_audio_q2       | 0.000167 |
# | mse_audio_q3       | 5.75e-05 |
# | mse_video          | 0.0081   |
# | mse_video_q0       | 0.0287   |
# | mse_video_q1       | 0.00395  |
# | mse_video_q2       | 0.000644 |
# | mse_video_q3       | 0.000105 |
# | param_norm         | 379      |
# | samples            | 5.26e+05 |
# | step               | 7.51e+04 |
# ---------------------------------

# %%
NUM_GPUS=1
DATA_DIR="/content/drive/MyDrive/environmental_png/train"
OUT_DIR="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train"

MODEL_FLAGS="--sr_attention_resolutions 8,16,32 --large_size 256 --small_size 64 --sr_learn_sigma True --sr_class_cond False --sr_num_channels 192 --sr_num_heads 4 --sr_num_res_blocks 2 --sr_resblock_updown True --use_fp16 True --sr_use_scale_shift_norm True"
DIFFUSION_FLAGS="--sr_diffusion_steps 1000 --noise_schedule linear"
TRAIN_FLAGS="--lr 1e-4 --batch_size 8 --devices 0 --log_interval 100 --sample_fn ddpm --save_interval 10000 --num_workers 8 --frame_gap 1 --use_db False --resume_checkpoint /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train/model070000.pt"

# !mpiexec --allow-run-as-root -n $NUM_GPUS python /content/drive/MyDrive/MM-Diffusion/py_scripts/image_sr_train.py \
  --data_dir "$DATA_DIR" --output_dir "$OUT_DIR" $MODEL_FLAGS $DIFFUSION_FLAGS $TRAIN_FLAGS
# Out:
# Logging to /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train
# Effective parameters:
#   <<< batch_size: 8
#   <<< data_dir: /content/drive/MyDrive/environmental_png/train
#   <<< devices: 0
#   <<< ema_rate: 0.9999
#   <<< fp16_scale_growth: 0.001
#   <<< frame_gap: 1
#   <<< large_size: 256
#   <<< log_interval: 100
#   <<< lr: 0.0001
#   <<< lr_anneal_steps: 0
#   <<< microbatch: -1
#   <<< noise_schedule: linear
#   <<< num_workers: 8
#   <<< output_dir: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train
#   <<< predict_xstart: False
#   <<< rescale_learned_sigmas: False
#   <<< rescale_timesteps: False
#   <<< resume_checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train/model070000.pt
#   <<< sample_fn: ddpm
#   <<< save_interval: 10000
#   <<< save_type: one
#   <<< schedule_sampler: uniform
#   <<< seed: 42
#   <<< small_size: 64
#   <<< sr_attention_resolutions: 8,16,32
#   <<< sr_class_cond: False
#   <<< sr_diffusion_steps: 1000
#   <<< sr_dropout: 0.0
#   <<< sr_learn_sigma: True
#   <<< sr_num_channels: 192
#   <<< sr_num_head_channels: -1
#   <<< sr_num_heads: 4
#   <<< sr_num_heads_upsample: -1
#   <<< sr_num_res_blocks: 2
#   <<< sr_resblock_updown: True
#   <<< sr_timestep_respacing:
#   <<< sr_use_scale_shift_norm: True
#   <<< use_checkpoint: False
#   <<< use_db: False
#   <<< use_fp16: True
#   <<< use_kl: False
#   <<< weight_decay: 0.0
# creating model...
# creating data loader...
# training...
# continue training from step 70000
# loading model from checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train/model070000.pt...
# **********keys not initialize in model***********
# **********keys not used in state_dict***********
# loading optimizer state from checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train/opt070000.pt
# loading EMA from checkpoint: /content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train/ema_0.9999_070000.pt...
# Total Parameters:311.03M
# Total Training Parameters:311.03M
# Total Loaded Parameters:311.03M
# ******DDP sync model done...
# len(data loader):900
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ---------------------------------
# |openai-2024-11-20-10:21:24|
# | current_grad_norm  | 0.048    |
# | current_param_norm | 639      |
# | grad_norm          | 0.048    |
# | lg_loss_scale      | 20       |
# | loss               | 0.000376 |
# | loss_q0            | 0.00105  |
# | loss_q1            | 0.000797 |
# | loss_q2            | 7.59e-05 |
# | loss_q3            | 6.28e-05 |
# | mse                | 0.000373 |
# | mse_q0             | 0.00104  |
# | mse_q1             | 0.000791 |
# | mse_q2             | 7.51e-05 |
# | mse_q3             | 6.21e-05 |
# | param_norm         | 639      |
# | samples            | 5.6e+05  |
# | step               | 7e+04    |
# | vb                 | 3.08e-06 |
# | vb_q0              | 9.45e-06 |
# | vb_q1              | 5.73e-06 |
# | vb_q2              | 7.44e-07 |
# | vb_q3              | 7.51e-07 |
# ---------------------------------
# saving model 0...
# saving model 0.9999...
# create samples
# 100%|██████████| 1000/1000 [02:49<00:00,  5.88it/s]
# 8 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 16 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 24 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 32 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 40 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 48 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 56 has sampled
# 100%|██████████| 1000/1000 [02:49<00:00,  5.89it/s]
# 64 has sampled
# created 64 samples
# ---------------------------------
# |openai-2024-11-20-10:45:22|
# | current_grad_norm  | 0.0268   |
# | current_param_norm | 639      |
# | grad_norm          | 0.025    |
# | lg_loss_scale      | 20.1     |
# | loss               | 0.0071   |
# | loss_q0            | 0.0261   |
# | loss_q1            | 0.000617 |
# | loss_q2            | 7.22e-05 |
# | loss_q3            | 2.57e-05 |
# | mse                | 0.00412  |
# | mse_q0             | 0.0149   |
# | mse_q1             | 0.000613 |
# | mse_q2             | 7.16e-05 |
# | mse_q3             | 2.54e-05 |
# | param_norm         | 639      |
# | samples            | 5.61e+05 |
# | step               | 7.01e+04 |
# | vb                 | 0.00298  |
# | vb_q0              | 0.0113   |
# | vb_q1              | 4.58e-06 |
# | vb_q2              | 6.5e-07  |
# | vb_q3              | 3.25e-07 |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 19.14700000000018
# ---------------------------------
# |openai-2024-11-20-10:46:15|
# | current_grad_norm  | 0.0399   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0352   |
# | lg_loss_scale      | 19.6     |
# | loss               | 0.00847  |
# | loss_q0            | 0.0332   |
# | loss_q1            | 0.000604 |
# | loss_q2            | 7.47e-05 |
# | loss_q3            | 3.27e-05 |
# | mse                | 0.00484  |
# | mse_q0             | 0.0187   |
# | mse_q1             | 0.000599 |
# | mse_q2             | 7.4e-05  |
# | mse_q3             | 3.23e-05 |
# | param_norm         | 639      |
# | samples            | 5.62e+05 |
# | step               | 7.02e+04 |
# | vb                 | 0.00362  |
# | vb_q0              | 0.0145   |
# | vb_q1              | 4.77e-06 |
# | vb_q2              | 6.8e-07  |
# | vb_q3              | 4.13e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:47:09|
# | current_grad_norm  | 0.0143   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0226   |
# | lg_loss_scale      | 19.2     |
# | loss               | 0.00415  |
# | loss_q0            | 0.0167   |
# | loss_q1            | 0.000569 |
# | loss_q2            | 6.64e-05 |
# | loss_q3            | 2.23e-05 |
# | mse                | 0.00376  |
# | mse_q0             | 0.0151   |
# | mse_q1             | 0.000565 |
# | mse_q2             | 6.57e-05 |
# | mse_q3             | 2.2e-05  |
# | param_norm         | 639      |
# | samples            | 5.62e+05 |
# | step               | 7.03e+04 |
# | vb                 | 0.000389 |
# | vb_q0              | 0.00162  |
# | vb_q1              | 4.34e-06 |
# | vb_q2              | 6.07e-07 |
# | vb_q3              | 2.8e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:48:02|
# | current_grad_norm  | 0.0149   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0266   |
# | lg_loss_scale      | 19.3     |
# | loss               | 0.00493  |
# | loss_q0            | 0.0205   |
# | loss_q1            | 0.000663 |
# | loss_q2            | 7.54e-05 |
# | loss_q3            | 2.92e-05 |
# | mse                | 0.00424  |
# | mse_q0             | 0.0175   |
# | mse_q1             | 0.000658 |
# | mse_q2             | 7.47e-05 |
# | mse_q3             | 2.88e-05 |
# | param_norm         | 639      |
# | samples            | 5.63e+05 |
# | step               | 7.04e+04 |
# | vb                 | 0.000689 |
# | vb_q0              | 0.00297  |
# | vb_q1              | 5.02e-06 |
# | vb_q2              | 6.84e-07 |
# | vb_q3              | 3.78e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:48:56|
# | current_grad_norm  | 0.014    |
# | current_param_norm | 639      |
# | grad_norm          | 0.0221   |
# | lg_loss_scale      | 19.4     |
# | loss               | 0.00451  |
# | loss_q0            | 0.0168   |
# | loss_q1            | 0.000579 |
# | loss_q2            | 6.26e-05 |
# | loss_q3            | 2.25e-05 |
# | mse                | 0.00413  |
# | mse_q0             | 0.0154   |
# | mse_q1             | 0.000575 |
# | mse_q2             | 6.2e-05  |
# | mse_q3             | 2.23e-05 |
# | param_norm         | 639      |
# | samples            | 5.64e+05 |
# | step               | 7.05e+04 |
# | vb                 | 0.00038  |
# | vb_q0              | 0.00147  |
# | vb_q1              | 4.3e-06  |
# | vb_q2              | 5.67e-07 |
# | vb_q3              | 2.88e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:49:50|
# | current_grad_norm  | 0.0273   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0238   |
# | lg_loss_scale      | 19.5     |
# | loss               | 0.00371  |
# | loss_q0            | 0.0141   |
# | loss_q1            | 0.000581 |
# | loss_q2            | 6.91e-05 |
# | loss_q3            | 2.17e-05 |
# | mse                | 0.0034   |
# | mse_q0             | 0.0128   |
# | mse_q1             | 0.000576 |
# | mse_q2             | 6.85e-05 |
# | mse_q3             | 2.14e-05 |
# | param_norm         | 639      |
# | samples            | 5.65e+05 |
# | step               | 7.06e+04 |
# | vb                 | 0.000316 |
# | vb_q0              | 0.00125  |
# | vb_q1              | 4.29e-06 |
# | vb_q2              | 6.22e-07 |
# | vb_q3              | 2.7e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:50:43|
# | current_grad_norm  | 0.0199   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0216   |
# | lg_loss_scale      | 19.6     |
# | loss               | 0.0061   |
# | loss_q0            | 0.0229   |
# | loss_q1            | 0.000569 |
# | loss_q2            | 6.92e-05 |
# | loss_q3            | 2.28e-05 |
# | mse                | 0.00433  |
# | mse_q0             | 0.016    |
# | mse_q1             | 0.000565 |
# | mse_q2             | 6.86e-05 |
# | mse_q3             | 2.25e-05 |
# | param_norm         | 639      |
# | samples            | 5.66e+05 |
# | step               | 7.07e+04 |
# | vb                 | 0.00177  |
# | vb_q0              | 0.00681  |
# | vb_q1              | 4.18e-06 |
# | vb_q2              | 6.22e-07 |
# | vb_q3              | 2.84e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:51:37|
# | current_grad_norm  | 0.0121   |
# | current_param_norm | 639      |
# | grad_norm          | 0.027    |
# | lg_loss_scale      | 19.7     |
# | loss               | 0.00312  |
# | loss_q0            | 0.0132   |
# | loss_q1            | 0.000633 |
# | loss_q2            | 6.78e-05 |
# | loss_q3            | 2.53e-05 |
# | mse                | 0.00258  |
# | mse_q0             | 0.0107   |
# | mse_q1             | 0.000628 |
# | mse_q2             | 6.72e-05 |
# | mse_q3             | 2.49e-05 |
# | param_norm         | 639      |
# | samples            | 5.66e+05 |
# | step               | 7.08e+04 |
# | vb                 | 0.000542 |
# | vb_q0              | 0.00242  |
# | vb_q1              | 4.67e-06 |
# | vb_q2              | 6.19e-07 |
# | vb_q3              | 3.17e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:52:31|
# | current_grad_norm  | 0.0243   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0285   |
# | lg_loss_scale      | 19.8     |
# | loss               | 0.00544  |
# | loss_q0            | 0.0216   |
# | loss_q1            | 0.000625 |
# | loss_q2            | 7.66e-05 |
# | loss_q3            | 3.11e-05 |
# | mse                | 0.00475  |
# | mse_q0             | 0.0188   |
# | mse_q1             | 0.000621 |
# | mse_q2             | 7.59e-05 |
# | mse_q3             | 3.07e-05 |
# | param_norm         | 639      |
# | samples            | 5.67e+05 |
# | step               | 7.09e+04 |
# | vb                 | 0.000686 |
# | vb_q0              | 0.00282  |
# | vb_q1              | 4.6e-06  |
# | vb_q2              | 6.93e-07 |
# | vb_q3              | 3.9e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:53:24|
# | current_grad_norm  | 0.0405   |
# | current_param_norm | 639      |
# | grad_norm          | 0.0314   |
# | lg_loss_scale      | 19.9     |
# | loss               | 0.00603  |
# | loss_q0            | 0.0251   |
# | loss_q1            | 0.000648 |
# | loss_q2            | 7.05e-05 |
# | loss_q3            | 2.89e-05 |
# | mse                | 0.0042   |
# | mse_q0             | 0.0173   |
# | mse_q1             | 0.000643 |
# | mse_q2             | 6.99e-05 |
# | mse_q3             | 2.85e-05 |
# | param_norm         | 639      |
# | samples            | 5.68e+05 |
# | step               | 7.1e+04  |
# | vb                 | 0.00183  |
# | vb_q0              | 0.00787  |
# | vb_q1              | 4.8e-06  |
# | vb_q2              | 6.42e-07 |
# | vb_q3              | 3.69e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:54:17|
# | current_grad_norm  | 0.0225   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0271   |
# | lg_loss_scale      | 20       |
# | loss               | 0.0049   |
# | loss_q0            | 0.0186   |
# | loss_q1            | 0.000641 |
# | loss_q2            | 8.66e-05 |
# | loss_q3            | 3.16e-05 |
# | mse                | 0.00425  |
# | mse_q0             | 0.0161   |
# | mse_q1             | 0.000636 |
# | mse_q2             | 8.58e-05 |
# | mse_q3             | 3.12e-05 |
# | param_norm         | 639      |
# | samples            | 5.69e+05 |
# | step               | 7.11e+04 |
# | vb                 | 0.000646 |
# | vb_q0              | 0.00254  |
# | vb_q1              | 4.78e-06 |
# | vb_q2              | 7.79e-07 |
# | vb_q3              | 4.02e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:55:10|
# | current_grad_norm  | 0.0308   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0265   |
# | lg_loss_scale      | 20.1     |
# | loss               | 0.00704  |
# | loss_q0            | 0.0283   |
# | loss_q1            | 0.000594 |
# | loss_q2            | 7.09e-05 |
# | loss_q3            | 2.92e-05 |
# | mse                | 0.00442  |
# | mse_q0             | 0.0175   |
# | mse_q1             | 0.00059  |
# | mse_q2             | 7.03e-05 |
# | mse_q3             | 2.88e-05 |
# | param_norm         | 640      |
# | samples            | 5.7e+05  |
# | step               | 7.12e+04 |
# | vb                 | 0.00263  |
# | vb_q0              | 0.0108   |
# | vb_q1              | 4.4e-06  |
# | vb_q2              | 6.46e-07 |
# | vb_q3              | 3.7e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:56:04|
# | current_grad_norm  | 0.0121   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0251   |
# | lg_loss_scale      | 20.2     |
# | loss               | 0.00479  |
# | loss_q0            | 0.0172   |
# | loss_q1            | 0.000558 |
# | loss_q2            | 7.25e-05 |
# | loss_q3            | 2.64e-05 |
# | mse                | 0.00441  |
# | mse_q0             | 0.0158   |
# | mse_q1             | 0.000554 |
# | mse_q2             | 7.19e-05 |
# | mse_q3             | 2.61e-05 |
# | param_norm         | 640      |
# | samples            | 5.7e+05  |
# | step               | 7.13e+04 |
# | vb                 | 0.000374 |
# | vb_q0              | 0.00138  |
# | vb_q1              | 4.12e-06 |
# | vb_q2              | 6.62e-07 |
# | vb_q3              | 3.35e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:56:58|
# | current_grad_norm  | 0.0312   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0257   |
# | lg_loss_scale      | 20.3     |
# | loss               | 0.00586  |
# | loss_q0            | 0.0249   |
# | loss_q1            | 0.000557 |
# | loss_q2            | 7.09e-05 |
# | loss_q3            | 2.49e-05 |
# | mse                | 0.00411  |
# | mse_q0             | 0.0173   |
# | mse_q1             | 0.000552 |
# | mse_q2             | 7.02e-05 |
# | mse_q3             | 2.46e-05 |
# | param_norm         | 640      |
# | samples            | 5.71e+05 |
# | step               | 7.14e+04 |
# | vb                 | 0.00175  |
# | vb_q0              | 0.00765  |
# | vb_q1              | 4.11e-06 |
# | vb_q2              | 6.35e-07 |
# | vb_q3              | 3.13e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:57:52|
# | current_grad_norm  | 0.0354   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0333   |
# | lg_loss_scale      | 20.4     |
# | loss               | 0.00918  |
# | loss_q0            | 0.034    |
# | loss_q1            | 0.000555 |
# | loss_q2            | 8.51e-05 |
# | loss_q3            | 3.32e-05 |
# | mse                | 0.00531  |
# | mse_q0             | 0.0194   |
# | mse_q1             | 0.000551 |
# | mse_q2             | 8.43e-05 |
# | mse_q3             | 3.27e-05 |
# | param_norm         | 640      |
# | samples            | 5.72e+05 |
# | step               | 7.15e+04 |
# | vb                 | 0.00386  |
# | vb_q0              | 0.0146   |
# | vb_q1              | 4.08e-06 |
# | vb_q2              | 7.67e-07 |
# | vb_q3              | 4.2e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:58:45|
# | current_grad_norm  | 0.0249   |
# | current_param_norm | 640      |
# | grad_norm          | 0.023    |
# | lg_loss_scale      | 20.5     |
# | loss               | 0.00463  |
# | loss_q0            | 0.0185   |
# | loss_q1            | 0.000524 |
# | loss_q2            | 6.98e-05 |
# | loss_q3            | 2.22e-05 |
# | mse                | 0.00389  |
# | mse_q0             | 0.0155   |
# | mse_q1             | 0.00052  |
# | mse_q2             | 6.92e-05 |
# | mse_q3             | 2.19e-05 |
# | param_norm         | 640      |
# | samples            | 5.73e+05 |
# | step               | 7.16e+04 |
# | vb                 | 0.000735 |
# | vb_q0              | 0.00303  |
# | vb_q1              | 3.87e-06 |
# | vb_q2              | 6.28e-07 |
# | vb_q3              | 2.79e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-10:59:39|
# | current_grad_norm  | 0.0155   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0276   |
# | lg_loss_scale      | 20.6     |
# | loss               | 0.00739  |
# | loss_q0            | 0.0286   |
# | loss_q1            | 0.000556 |
# | loss_q2            | 6.85e-05 |
# | loss_q3            | 2.78e-05 |
# | mse                | 0.00468  |
# | mse_q0             | 0.0179   |
# | mse_q1             | 0.000552 |
# | mse_q2             | 6.78e-05 |
# | mse_q3             | 2.74e-05 |
# | param_norm         | 640      |
# | samples            | 5.74e+05 |
# | step               | 7.17e+04 |
# | vb                 | 0.0027   |
# | vb_q0              | 0.0107   |
# | vb_q1              | 4.1e-06  |
# | vb_q2              | 6.27e-07 |
# | vb_q3              | 3.51e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:00:33|
# | current_grad_norm  | 0.0129   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0225   |
# | lg_loss_scale      | 20.7     |
# | loss               | 0.00306  |
# | loss_q0            | 0.013    |
# | loss_q1            | 0.00052  |
# | loss_q2            | 7.21e-05 |
# | loss_q3            | 2.08e-05 |
# | mse                | 0.00284  |
# | mse_q0             | 0.012    |
# | mse_q1             | 0.000516 |
# | mse_q2             | 7.15e-05 |
# | mse_q3             | 2.06e-05 |
# | param_norm         | 640      |
# | samples            | 5.74e+05 |
# | step               | 7.18e+04 |
# | vb                 | 0.000221 |
# | vb_q0              | 0.000984 |
# | vb_q1              | 3.83e-06 |
# | vb_q2              | 6.46e-07 |
# | vb_q3              | 2.61e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:01:26|
# | current_grad_norm  | 0.0453   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0245   |
# | lg_loss_scale      | 20.8     |
# | loss               | 0.00793  |
# | loss_q0            | 0.0337   |
# | loss_q1            | 0.000614 |
# | loss_q2            | 6.37e-05 |
# | loss_q3            | 2.78e-05 |
# | mse                | 0.00493  |
# | mse_q0             | 0.0206   |
# | mse_q1             | 0.000609 |
# | mse_q2             | 6.31e-05 |
# | mse_q3             | 2.75e-05 |
# | param_norm         | 640      |
# | samples            | 5.75e+05 |
# | step               | 7.19e+04 |
# | vb                 | 0.003    |
# | vb_q0              | 0.0131   |
# | vb_q1              | 4.53e-06 |
# | vb_q2              | 5.87e-07 |
# | vb_q3              | 3.47e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:02:19|
# | current_grad_norm  | 0.0179   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0283   |
# | lg_loss_scale      | 20.9     |
# | loss               | 0.00807  |
# | loss_q0            | 0.0352   |
# | loss_q1            | 0.000634 |
# | loss_q2            | 8.38e-05 |
# | loss_q3            | 3.39e-05 |
# | mse                | 0.00442  |
# | mse_q0             | 0.0189   |
# | mse_q1             | 0.000629 |
# | mse_q2             | 8.3e-05  |
# | mse_q3             | 3.34e-05 |
# | param_norm         | 640      |
# | samples            | 5.76e+05 |
# | step               | 7.2e+04  |
# | vb                 | 0.00365  |
# | vb_q0              | 0.0163   |
# | vb_q1              | 4.68e-06 |
# | vb_q2              | 7.51e-07 |
# | vb_q3              | 4.32e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:03:12|
# | current_grad_norm  | 0.0207   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0237   |
# | lg_loss_scale      | 21       |
# | loss               | 0.00547  |
# | loss_q0            | 0.021    |
# | loss_q1            | 0.000606 |
# | loss_q2            | 6.83e-05 |
# | loss_q3            | 2.61e-05 |
# | mse                | 0.00484  |
# | mse_q0             | 0.0185   |
# | mse_q1             | 0.000601 |
# | mse_q2             | 6.76e-05 |
# | mse_q3             | 2.58e-05 |
# | param_norm         | 640      |
# | samples            | 5.77e+05 |
# | step               | 7.21e+04 |
# | vb                 | 0.000635 |
# | vb_q0              | 0.00252  |
# | vb_q1              | 4.48e-06 |
# | vb_q2              | 6.22e-07 |
# | vb_q3              | 3.28e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:04:06|
# | current_grad_norm  | 0.0385   |
# | current_param_norm | 640      |
# | grad_norm          | 0.0274   |
# | lg_loss_scale      | 21.1     |
# | loss               | 0.00656  |
# | loss_q0            | 0.0243   |
# | loss_q1            | 0.000513 |
# | loss_q2            | 7.57e-05 |
# | loss_q3            | 2.81e-05 |
# | mse                | 0.00443  |
# | mse_q0             | 0.0162   |
# | mse_q1             | 0.000509 |
# | mse_q2             | 7.5e-05  |
# | mse_q3             | 2.77e-05 |
# | param_norm         | 640      |
# | samples            | 5.78e+05 |
# | step               | 7.22e+04 |
# | vb                 | 0.00213  |
# | vb_q0              | 0.00808  |
# | vb_q1              | 3.77e-06 |
# | vb_q2              | 6.92e-07 |
# | vb_q3              | 3.5e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:05:00|
# | current_grad_norm  | 0.0533   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0311   |
# | lg_loss_scale      | 21.2     |
# | loss               | 0.00699  |
# | loss_q0            | 0.0275   |
# | loss_q1            | 0.000601 |
# | loss_q2            | 8.11e-05 |
# | loss_q3            | 3.24e-05 |
# | mse                | 0.00441  |
# | mse_q0             | 0.0171   |
# | mse_q1             | 0.000597 |
# | mse_q2             | 8.04e-05 |
# | mse_q3             | 3.2e-05  |
# | param_norm         | 641      |
# | samples            | 5.78e+05 |
# | step               | 7.23e+04 |
# | vb                 | 0.00257  |
# | vb_q0              | 0.0104   |
# | vb_q1              | 4.43e-06 |
# | vb_q2              | 7.31e-07 |
# | vb_q3              | 4.15e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:05:54|
# | current_grad_norm  | 0.0288   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0258   |
# | lg_loss_scale      | 21.3     |
# | loss               | 0.00569  |
# | loss_q0            | 0.0206   |
# | loss_q1            | 0.000479 |
# | loss_q2            | 7.02e-05 |
# | loss_q3            | 2.77e-05 |
# | mse                | 0.00516  |
# | mse_q0             | 0.0187   |
# | mse_q1             | 0.000475 |
# | mse_q2             | 6.96e-05 |
# | mse_q3             | 2.74e-05 |
# | param_norm         | 641      |
# | samples            | 5.79e+05 |
# | step               | 7.24e+04 |
# | vb                 | 0.000526 |
# | vb_q0              | 0.00195  |
# | vb_q1              | 3.55e-06 |
# | vb_q2              | 6.35e-07 |
# | vb_q3              | 3.45e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:06:48|
# | current_grad_norm  | 0.012    |
# | current_param_norm | 641      |
# | grad_norm          | 0.0249   |
# | lg_loss_scale      | 21.4     |
# | loss               | 0.0039   |
# | loss_q0            | 0.0141   |
# | loss_q1            | 0.000531 |
# | loss_q2            | 6.14e-05 |
# | loss_q3            | 2.56e-05 |
# | mse                | 0.00357  |
# | mse_q0             | 0.0129   |
# | mse_q1             | 0.000527 |
# | mse_q2             | 6.09e-05 |
# | mse_q3             | 2.53e-05 |
# | param_norm         | 641      |
# | samples            | 5.8e+05  |
# | step               | 7.25e+04 |
# | vb                 | 0.00033  |
# | vb_q0              | 0.00124  |
# | vb_q1              | 3.91e-06 |
# | vb_q2              | 5.62e-07 |
# | vb_q3              | 3.2e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:07:41|
# | current_grad_norm  | 0.0171   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0202   |
# | lg_loss_scale      | 21.5     |
# | loss               | 0.00407  |
# | loss_q0            | 0.0166   |
# | loss_q1            | 0.000609 |
# | loss_q2            | 5.32e-05 |
# | loss_q3            | 2.04e-05 |
# | mse                | 0.00357  |
# | mse_q0             | 0.0144   |
# | mse_q1             | 0.000605 |
# | mse_q2             | 5.27e-05 |
# | mse_q3             | 2.01e-05 |
# | param_norm         | 641      |
# | samples            | 5.81e+05 |
# | step               | 7.26e+04 |
# | vb                 | 0.000499 |
# | vb_q0              | 0.00212  |
# | vb_q1              | 4.49e-06 |
# | vb_q2              | 4.9e-07  |
# | vb_q3              | 2.56e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:08:35|
# | current_grad_norm  | 0.0124   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0206   |
# | lg_loss_scale      | 21.6     |
# | loss               | 0.00443  |
# | loss_q0            | 0.0178   |
# | loss_q1            | 0.000548 |
# | loss_q2            | 6.54e-05 |
# | loss_q3            | 2.09e-05 |
# | mse                | 0.00399  |
# | mse_q0             | 0.016    |
# | mse_q1             | 0.000544 |
# | mse_q2             | 6.48e-05 |
# | mse_q3             | 2.06e-05 |
# | param_norm         | 641      |
# | samples            | 5.82e+05 |
# | step               | 7.27e+04 |
# | vb                 | 0.000442 |
# | vb_q0              | 0.00184  |
# | vb_q1              | 4.04e-06 |
# | vb_q2              | 5.94e-07 |
# | vb_q3              | 2.61e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:09:29|
# | current_grad_norm  | 0.0368   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0257   |
# | lg_loss_scale      | 21.7     |
# | loss               | 0.00699  |
# | loss_q0            | 0.0258   |
# | loss_q1            | 0.000557 |
# | loss_q2            | 6.44e-05 |
# | loss_q3            | 2.56e-05 |
# | mse                | 0.00419  |
# | mse_q0             | 0.0152   |
# | mse_q1             | 0.000553 |
# | mse_q2             | 6.38e-05 |
# | mse_q3             | 2.53e-05 |
# | param_norm         | 641      |
# | samples            | 5.82e+05 |
# | step               | 7.28e+04 |
# | vb                 | 0.0028   |
# | vb_q0              | 0.0105   |
# | vb_q1              | 4.12e-06 |
# | vb_q2              | 5.86e-07 |
# | vb_q3              | 3.26e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:10:21|
# | current_grad_norm  | 0.0195   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0317   |
# | lg_loss_scale      | 21.8     |
# | loss               | 0.00564  |
# | loss_q0            | 0.0211   |
# | loss_q1            | 0.000587 |
# | loss_q2            | 7.4e-05  |
# | loss_q3            | 3.07e-05 |
# | mse                | 0.00413  |
# | mse_q0             | 0.0153   |
# | mse_q1             | 0.000583 |
# | mse_q2             | 7.33e-05 |
# | mse_q3             | 3.03e-05 |
# | param_norm         | 641      |
# | samples            | 5.83e+05 |
# | step               | 7.29e+04 |
# | vb                 | 0.00151  |
# | vb_q0              | 0.00583  |
# | vb_q1              | 4.34e-06 |
# | vb_q2              | 6.7e-07  |
# | vb_q3              | 3.88e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:11:15|
# | current_grad_norm  | 0.0254   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0254   |
# | lg_loss_scale      | 21.9     |
# | loss               | 0.00551  |
# | loss_q0            | 0.0183   |
# | loss_q1            | 0.000542 |
# | loss_q2            | 6.81e-05 |
# | loss_q3            | 2.68e-05 |
# | mse                | 0.00418  |
# | mse_q0             | 0.0138   |
# | mse_q1             | 0.000538 |
# | mse_q2             | 6.75e-05 |
# | mse_q3             | 2.65e-05 |
# | param_norm         | 641      |
# | samples            | 5.84e+05 |
# | step               | 7.3e+04  |
# | vb                 | 0.00134  |
# | vb_q0              | 0.00456  |
# | vb_q1              | 3.99e-06 |
# | vb_q2              | 6.2e-07  |
# | vb_q3              | 3.36e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:12:09|
# | current_grad_norm  | 0.0303   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0295   |
# | lg_loss_scale      | 22       |
# | loss               | 0.0072   |
# | loss_q0            | 0.026    |
# | loss_q1            | 0.000548 |
# | loss_q2            | 7.03e-05 |
# | loss_q3            | 3.22e-05 |
# | mse                | 0.00506  |
# | mse_q0             | 0.0181   |
# | mse_q1             | 0.000544 |
# | mse_q2             | 6.97e-05 |
# | mse_q3             | 3.18e-05 |
# | param_norm         | 641      |
# | samples            | 5.85e+05 |
# | step               | 7.31e+04 |
# | vb                 | 0.00214  |
# | vb_q0              | 0.00787  |
# | vb_q1              | 4.07e-06 |
# | vb_q2              | 6.42e-07 |
# | vb_q3              | 4.09e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:13:03|
# | current_grad_norm  | 0.0288   |
# | current_param_norm | 641      |
# | grad_norm          | 0.0292   |
# | lg_loss_scale      | 22.1     |
# | loss               | 0.00439  |
# | loss_q0            | 0.0163   |
# | loss_q1            | 0.000575 |
# | loss_q2            | 6.97e-05 |
# | loss_q3            | 3.3e-05  |
# | mse                | 0.00402  |
# | mse_q0             | 0.0149   |
# | mse_q1             | 0.000571 |
# | mse_q2             | 6.9e-05  |
# | mse_q3             | 3.26e-05 |
# | param_norm         | 641      |
# | samples            | 5.86e+05 |
# | step               | 7.32e+04 |
# | vb                 | 0.000375 |
# | vb_q0              | 0.00144  |
# | vb_q1              | 4.25e-06 |
# | vb_q2              | 6.39e-07 |
# | vb_q3              | 4.13e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:13:56|
# | current_grad_norm  | 0.0351   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0249   |
# | lg_loss_scale      | 22.2     |
# | loss               | 0.00674  |
# | loss_q0            | 0.0253   |
# | loss_q1            | 0.000575 |
# | loss_q2            | 6.4e-05  |
# | loss_q3            | 2.28e-05 |
# | mse                | 0.00507  |
# | mse_q0             | 0.0189   |
# | mse_q1             | 0.000571 |
# | mse_q2             | 6.34e-05 |
# | mse_q3             | 2.25e-05 |
# | param_norm         | 641      |
# | samples            | 5.86e+05 |
# | step               | 7.33e+04 |
# | vb                 | 0.00166  |
# | vb_q0              | 0.0064   |
# | vb_q1              | 4.23e-06 |
# | vb_q2              | 5.82e-07 |
# | vb_q3              | 2.83e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:14:50|
# | current_grad_norm  | 0.0395   |
# | current_param_norm | 642      |
# | grad_norm          | 0.021    |
# | lg_loss_scale      | 22.3     |
# | loss               | 0.00469  |
# | loss_q0            | 0.017    |
# | loss_q1            | 0.00056  |
# | loss_q2            | 6.22e-05 |
# | loss_q3            | 2.04e-05 |
# | mse                | 0.00424  |
# | mse_q0             | 0.0154   |
# | mse_q1             | 0.000556 |
# | mse_q2             | 6.17e-05 |
# | mse_q3             | 2.01e-05 |
# | param_norm         | 642      |
# | samples            | 5.87e+05 |
# | step               | 7.34e+04 |
# | vb                 | 0.000442 |
# | vb_q0              | 0.00166  |
# | vb_q1              | 4.14e-06 |
# | vb_q2              | 5.62e-07 |
# | vb_q3              | 2.54e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:15:44|
# | current_grad_norm  | 0.0185   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0223   |
# | lg_loss_scale      | 22.4     |
# | loss               | 0.00348  |
# | loss_q0            | 0.0135   |
# | loss_q1            | 0.00051  |
# | loss_q2            | 7.23e-05 |
# | loss_q3            | 2.45e-05 |
# | mse                | 0.00326  |
# | mse_q0             | 0.0126   |
# | mse_q1             | 0.000506 |
# | mse_q2             | 7.16e-05 |
# | mse_q3             | 2.42e-05 |
# | param_norm         | 642      |
# | samples            | 5.88e+05 |
# | step               | 7.35e+04 |
# | vb                 | 0.000218 |
# | vb_q0              | 0.000879 |
# | vb_q1              | 3.77e-06 |
# | vb_q2              | 6.52e-07 |
# | vb_q3              | 3.08e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:16:38|
# | current_grad_norm  | 0.00802  |
# | current_param_norm | 642      |
# | grad_norm          | 0.022    |
# | lg_loss_scale      | 22.5     |
# | loss               | 0.00412  |
# | loss_q0            | 0.0159   |
# | loss_q1            | 0.000586 |
# | loss_q2            | 6.22e-05 |
# | loss_q3            | 2.19e-05 |
# | mse                | 0.00363  |
# | mse_q0             | 0.014    |
# | mse_q1             | 0.000582 |
# | mse_q2             | 6.17e-05 |
# | mse_q3             | 2.16e-05 |
# | param_norm         | 642      |
# | samples            | 5.89e+05 |
# | step               | 7.36e+04 |
# | vb                 | 0.000481 |
# | vb_q0              | 0.00194  |
# | vb_q1              | 4.34e-06 |
# | vb_q2              | 5.63e-07 |
# | vb_q3              | 2.72e-07 |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 21.660000000004473
# ---------------------------------
# |openai-2024-11-20-11:17:32|
# | current_grad_norm  | 0.0371   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0228   |
# | lg_loss_scale      | 22.3     |
# | loss               | 0.00741  |
# | loss_q0            | 0.0314   |
# | loss_q1            | 0.000528 |
# | loss_q2            | 7.51e-05 |
# | loss_q3            | 2.35e-05 |
# | mse                | 0.00432  |
# | mse_q0             | 0.018    |
# | mse_q1             | 0.000524 |
# | mse_q2             | 7.45e-05 |
# | mse_q3             | 2.32e-05 |
# | param_norm         | 642      |
# | samples            | 5.9e+05  |
# | step               | 7.37e+04 |
# | vb                 | 0.0031   |
# | vb_q0              | 0.0134   |
# | vb_q1              | 3.92e-06 |
# | vb_q2              | 6.72e-07 |
# | vb_q3              | 2.98e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:18:25|
# | current_grad_norm  | 0.0109   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0228   |
# | lg_loss_scale      | 21.7     |
# | loss               | 0.00478  |
# | loss_q0            | 0.0181   |
# | loss_q1            | 0.00061  |
# | loss_q2            | 6.93e-05 |
# | loss_q3            | 2.48e-05 |
# | mse                | 0.00435  |
# | mse_q0             | 0.0165   |
# | mse_q1             | 0.000605 |
# | mse_q2             | 6.87e-05 |
# | mse_q3             | 2.45e-05 |
# | param_norm         | 642      |
# | samples            | 5.9e+05  |
# | step               | 7.38e+04 |
# | vb                 | 0.000431 |
# | vb_q0              | 0.00169  |
# | vb_q1              | 4.51e-06 |
# | vb_q2              | 6.15e-07 |
# | vb_q3              | 3.1e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:19:18|
# | current_grad_norm  | 0.0426   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0258   |
# | lg_loss_scale      | 21.8     |
# | loss               | 0.00504  |
# | loss_q0            | 0.0171   |
# | loss_q1            | 0.000539 |
# | loss_q2            | 6.94e-05 |
# | loss_q3            | 2.45e-05 |
# | mse                | 0.00443  |
# | mse_q0             | 0.015    |
# | mse_q1             | 0.000535 |
# | mse_q2             | 6.88e-05 |
# | mse_q3             | 2.42e-05 |
# | param_norm         | 642      |
# | samples            | 5.91e+05 |
# | step               | 7.39e+04 |
# | vb                 | 0.000605 |
# | vb_q0              | 0.00211  |
# | vb_q1              | 3.96e-06 |
# | vb_q2              | 6.21e-07 |
# | vb_q3              | 3.07e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:20:11|
# | current_grad_norm  | 0.02     |
# | current_param_norm | 642      |
# | grad_norm          | 0.0365   |
# | lg_loss_scale      | 21.9     |
# | loss               | 0.00631  |
# | loss_q0            | 0.0242   |
# | loss_q1            | 0.000619 |
# | loss_q2            | 9.67e-05 |
# | loss_q3            | 4.4e-05  |
# | mse                | 0.00489  |
# | mse_q0             | 0.0186   |
# | mse_q1             | 0.000615 |
# | mse_q2             | 9.58e-05 |
# | mse_q3             | 4.35e-05 |
# | param_norm         | 642      |
# | samples            | 5.92e+05 |
# | step               | 7.4e+04  |
# | vb                 | 0.00142  |
# | vb_q0              | 0.00562  |
# | vb_q1              | 4.61e-06 |
# | vb_q2              | 8.73e-07 |
# | vb_q3              | 5.56e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:21:05|
# | current_grad_norm  | 0.0213   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0272   |
# | lg_loss_scale      | 22       |
# | loss               | 0.00522  |
# | loss_q0            | 0.0208   |
# | loss_q1            | 0.000572 |
# | loss_q2            | 6.99e-05 |
# | loss_q3            | 3.04e-05 |
# | mse                | 0.00454  |
# | mse_q0             | 0.018    |
# | mse_q1             | 0.000568 |
# | mse_q2             | 6.92e-05 |
# | mse_q3             | 3e-05    |
# | param_norm         | 642      |
# | samples            | 5.93e+05 |
# | step               | 7.41e+04 |
# | vb                 | 0.000674 |
# | vb_q0              | 0.00278  |
# | vb_q1              | 4.23e-06 |
# | vb_q2              | 6.41e-07 |
# | vb_q3              | 3.82e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:21:59|
# | current_grad_norm  | 0.0229   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0243   |
# | lg_loss_scale      | 22.1     |
# | loss               | 0.00402  |
# | loss_q0            | 0.015    |
# | loss_q1            | 0.000654 |
# | loss_q2            | 6.04e-05 |
# | loss_q3            | 2.11e-05 |
# | mse                | 0.00368  |
# | mse_q0             | 0.0137   |
# | mse_q1             | 0.00065  |
# | mse_q2             | 5.99e-05 |
# | mse_q3             | 2.08e-05 |
# | param_norm         | 642      |
# | samples            | 5.94e+05 |
# | step               | 7.42e+04 |
# | vb                 | 0.000336 |
# | vb_q0              | 0.00131  |
# | vb_q1              | 4.87e-06 |
# | vb_q2              | 5.54e-07 |
# | vb_q3              | 2.68e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:22:52|
# | current_grad_norm  | 0.0221   |
# | current_param_norm | 642      |
# | grad_norm          | 0.0215   |
# | lg_loss_scale      | 22.2     |
# | loss               | 0.00399  |
# | loss_q0            | 0.0157   |
# | loss_q1            | 0.000568 |
# | loss_q2            | 6.45e-05 |
# | loss_q3            | 2.15e-05 |
# | mse                | 0.00373  |
# | mse_q0             | 0.0146   |
# | mse_q1             | 0.000564 |
# | mse_q2             | 6.4e-05  |
# | mse_q3             | 2.13e-05 |
# | param_norm         | 642      |
# | samples            | 5.94e+05 |
# | step               | 7.43e+04 |
# | vb                 | 0.000262 |
# | vb_q0              | 0.00107  |
# | vb_q1              | 4.21e-06 |
# | vb_q2              | 5.79e-07 |
# | vb_q3              | 2.69e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:23:46|
# | current_grad_norm  | 0.0116   |
# | current_param_norm | 642      |
# | grad_norm          | 0.031    |
# | lg_loss_scale      | 22.3     |
# | loss               | 0.00707  |
# | loss_q0            | 0.0238   |
# | loss_q1            | 0.000597 |
# | loss_q2            | 6.8e-05  |
# | loss_q3            | 3.1e-05  |
# | mse                | 0.0046   |
# | mse_q0             | 0.0153   |
# | mse_q1             | 0.000593 |
# | mse_q2             | 6.74e-05 |
# | mse_q3             | 3.06e-05 |
# | param_norm         | 642      |
# | samples            | 5.95e+05 |
# | step               | 7.44e+04 |
# | vb                 | 0.00247  |
# | vb_q0              | 0.00848  |
# | vb_q1              | 4.41e-06 |
# | vb_q2              | 6.23e-07 |
# | vb_q3              | 3.94e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:24:40|
# | current_grad_norm  | 0.0119   |
# | current_param_norm | 643      |
# | grad_norm          | 0.0245   |
# | lg_loss_scale      | 22.4     |
# | loss               | 0.00357  |
# | loss_q0            | 0.014    |
# | loss_q1            | 0.00051  |
# | loss_q2            | 6.92e-05 |
# | loss_q3            | 2.48e-05 |
# | mse                | 0.00321  |
# | mse_q0             | 0.0126   |
# | mse_q1             | 0.000506 |
# | mse_q2             | 6.86e-05 |
# | mse_q3             | 2.45e-05 |
# | param_norm         | 643      |
# | samples            | 5.96e+05 |
# | step               | 7.45e+04 |
# | vb                 | 0.000358 |
# | vb_q0              | 0.00147  |
# | vb_q1              | 3.76e-06 |
# | vb_q2              | 6.29e-07 |
# | vb_q3              | 3.15e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:25:34|
# | current_grad_norm  | 0.0239   |
# | current_param_norm | 643      |
# | grad_norm          | 0.0196   |
# | lg_loss_scale      | 22.5     |
# | loss               | 0.00417  |
# | loss_q0            | 0.0167   |
# | loss_q1            | 0.000534 |
# | loss_q2            | 5.79e-05 |
# | loss_q3            | 2.09e-05 |
# | mse                | 0.00375  |
# | mse_q0             | 0.0149   |
# | mse_q1             | 0.00053  |
# | mse_q2             | 5.74e-05 |
# | mse_q3             | 2.07e-05 |
# | param_norm         | 643      |
# | samples            | 5.97e+05 |
# | step               | 7.46e+04 |
# | vb                 | 0.000421 |
# | vb_q0              | 0.00175  |
# | vb_q1              | 3.95e-06 |
# | vb_q2              | 5.24e-07 |
# | vb_q3              | 2.63e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:26:27|
# | current_grad_norm  | 0.0138   |
# | current_param_norm | 643      |
# | grad_norm          | 0.0267   |
# | lg_loss_scale      | 22.6     |
# | loss               | 0.00356  |
# | loss_q0            | 0.0137   |
# | loss_q1            | 0.000545 |
# | loss_q2            | 6.87e-05 |
# | loss_q3            | 2.5e-05  |
# | mse                | 0.00332  |
# | mse_q0             | 0.0128   |
# | mse_q1             | 0.000541 |
# | mse_q2             | 6.81e-05 |
# | mse_q3             | 2.47e-05 |
# | param_norm         | 643      |
# | samples            | 5.98e+05 |
# | step               | 7.47e+04 |
# | vb                 | 0.000241 |
# | vb_q0              | 0.000974 |
# | vb_q1              | 4.03e-06 |
# | vb_q2              | 6.2e-07  |
# | vb_q3              | 3.12e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:27:20|
# | current_grad_norm  | 0.0118   |
# | current_param_norm | 643      |
# | grad_norm          | 0.0209   |
# | lg_loss_scale      | 22.7     |
# | loss               | 0.00293  |
# | loss_q0            | 0.012    |
# | loss_q1            | 0.000525 |
# | loss_q2            | 5.76e-05 |
# | loss_q3            | 2.06e-05 |
# | mse                | 0.00277  |
# | mse_q0             | 0.0113   |
# | mse_q1             | 0.000521 |
# | mse_q2             | 5.71e-05 |
# | mse_q3             | 2.03e-05 |
# | param_norm         | 643      |
# | samples            | 5.98e+05 |
# | step               | 7.48e+04 |
# | vb                 | 0.000157 |
# | vb_q0              | 0.000673 |
# | vb_q1              | 3.89e-06 |
# | vb_q2              | 5.22e-07 |
# | vb_q3              | 2.57e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:28:13|
# | current_grad_norm  | 0.0295   |
# | current_param_norm | 643      |
# | grad_norm          | 0.0424   |
# | lg_loss_scale      | 22.8     |
# | loss               | 0.0104   |
# | loss_q0            | 0.0428   |
# | loss_q1            | 0.00063  |
# | loss_q2            | 8.26e-05 |
# | loss_q3            | 4.38e-05 |
# | mse                | 0.00522  |
# | mse_q0             | 0.0211   |
# | mse_q1             | 0.000625 |
# | mse_q2             | 8.18e-05 |
# | mse_q3             | 4.32e-05 |
# | param_norm         | 643      |
# | samples            | 5.99e+05 |
# | step               | 7.49e+04 |
# | vb                 | 0.00519  |
# | vb_q0              | 0.0217   |
# | vb_q1              | 4.67e-06 |
# | vb_q2              | 7.53e-07 |
# | vb_q3              | 5.56e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:29:07|
# | current_grad_norm  | 0.021    |
# | current_param_norm | 643      |
# | grad_norm          | 0.0324   |
# | lg_loss_scale      | 22.9     |
# | loss               | 0.00529  |
# | loss_q0            | 0.0199   |
# | loss_q1            | 0.000528 |
# | loss_q2            | 7.93e-05 |
# | loss_q3            | 3.47e-05 |
# | mse                | 0.00388  |
# | mse_q0             | 0.0144   |
# | mse_q1             | 0.000524 |
# | mse_q2             | 7.86e-05 |
# | mse_q3             | 3.43e-05 |
# | param_norm         | 643      |
# | samples            | 6e+05    |
# | step               | 7.5e+04  |
# | vb                 | 0.00141  |
# | vb_q0              | 0.00544  |
# | vb_q1              | 3.92e-06 |
# | vb_q2              | 7.11e-07 |
# | vb_q3              | 4.36e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:30:01|
# | current_grad_norm  | 0.0189   |
# | current_param_norm | 643      |
# | grad_norm          | 0.0331   |
# | lg_loss_scale      | 23       |
# | loss               | 0.00752  |
# | loss_q0            | 0.0293   |
# | loss_q1            | 0.000525 |
# | loss_q2            | 7.18e-05 |
# | loss_q3            | 3.24e-05 |
# | mse                | 0.00399  |
# | mse_q0             | 0.0153   |
# | mse_q1             | 0.000521 |
# | mse_q2             | 7.11e-05 |
# | mse_q3             | 3.2e-05  |
# | param_norm         | 643      |
# | samples            | 6.01e+05 |
# | step               | 7.51e+04 |
# | vb                 | 0.00353  |
# | vb_q0              | 0.014    |
# | vb_q1              | 3.91e-06 |
# | vb_q2              | 6.47e-07 |
# | vb_q3              | 4.18e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:30:55|
# | current_grad_norm  | 0.016    |
# | current_param_norm | 643      |
# | grad_norm          | 0.0239   |
# | lg_loss_scale      | 23.1     |
# | loss               | 0.00467  |
# | loss_q0            | 0.0189   |
# | loss_q1            | 0.000516 |
# | loss_q2            | 6.76e-05 |
# | loss_q3            | 2.91e-05 |
# | mse                | 0.00382  |
# | mse_q0             | 0.0153   |
# | mse_q1             | 0.000513 |
# | mse_q2             | 6.7e-05  |
# | mse_q3             | 2.87e-05 |
# | param_norm         | 643      |
# | samples            | 6.02e+05 |
# | step               | 7.52e+04 |
# | vb                 | 0.000854 |
# | vb_q0              | 0.00357  |
# | vb_q1              | 3.82e-06 |
# | vb_q2              | 6.09e-07 |
# ...
# | loss_q2            | 7.88e-05 |
# | loss_q3            | 3.26e-05 |
# | mse                | 0.00501  |
# | mse_q0             | 0.0184   |
# | mse_q1             | 0.000486 |
# | mse_q2             | 7.81e-05 |
# | mse_q3             | 3.22e-05 |
# | param_norm         | 646      |
# | samples            | 6.26e+05 |
# | step               | 7.82e+04 |
# | vb                 | 0.00395  |
# | vb_q0              | 0.0149   |
# | vb_q1              | 3.62e-06 |
# | vb_q2              | 7.08e-07 |
# | vb_q3              | 4.1e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:58:36|
# | current_grad_norm  | 0.0202   |
# | current_param_norm | 646      |
# | grad_norm          | 0.0377   |
# | lg_loss_scale      | 22.2     |
# | loss               | 0.0102   |
# | loss_q0            | 0.041    |
# | loss_q1            | 0.000659 |
# | loss_q2            | 0.000105 |
# | loss_q3            | 6.88e-05 |
# | mse                | 0.00515  |
# | mse_q0             | 0.0202   |
# | mse_q1             | 0.000654 |
# | mse_q2             | 0.000104 |
# | mse_q3             | 6.8e-05  |
# | param_norm         | 646      |
# | samples            | 6.26e+05 |
# | step               | 7.83e+04 |
# | vb                 | 0.00509  |
# | vb_q0              | 0.0208   |
# | vb_q1              | 4.92e-06 |
# | vb_q2              | 9.68e-07 |
# | vb_q3              | 8.66e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-11:59:30|
# | current_grad_norm  | 0.0251   |
# | current_param_norm | 646      |
# | grad_norm          | 0.0313   |
# | lg_loss_scale      | 22.3     |
# | loss               | 0.00446  |
# | loss_q0            | 0.0157   |
# | loss_q1            | 0.000604 |
# | loss_q2            | 9.8e-05  |
# | loss_q3            | 5.65e-05 |
# | mse                | 0.00414  |
# | mse_q0             | 0.0145   |
# | mse_q1             | 0.0006   |
# | mse_q2             | 9.71e-05 |
# | mse_q3             | 5.58e-05 |
# | param_norm         | 646      |
# | samples            | 6.27e+05 |
# | step               | 7.84e+04 |
# | vb                 | 0.000314 |
# | vb_q0              | 0.00114  |
# | vb_q1              | 4.47e-06 |
# | vb_q2              | 8.94e-07 |
# | vb_q3              | 7.14e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:00:22|
# | current_grad_norm  | 0.0231   |
# | current_param_norm | 646      |
# | grad_norm          | 0.0281   |
# | lg_loss_scale      | 22.4     |
# | loss               | 0.0055   |
# | loss_q0            | 0.0221   |
# | loss_q1            | 0.000519 |
# | loss_q2            | 6.51e-05 |
# | loss_q3            | 2.61e-05 |
# | mse                | 0.00398  |
# | mse_q0             | 0.0158   |
# | mse_q1             | 0.000515 |
# | mse_q2             | 6.45e-05 |
# | mse_q3             | 2.57e-05 |
# | param_norm         | 646      |
# | samples            | 6.28e+05 |
# | step               | 7.85e+04 |
# | vb                 | 0.00152  |
# | vb_q0              | 0.00628  |
# | vb_q1              | 3.85e-06 |
# | vb_q2              | 5.94e-07 |
# | vb_q3              | 3.25e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:01:16|
# | current_grad_norm  | 0.0324   |
# | current_param_norm | 646      |
# | grad_norm          | 0.0227   |
# | lg_loss_scale      | 22.5     |
# | loss               | 0.00462  |
# | loss_q0            | 0.0173   |
# | loss_q1            | 0.000603 |
# | loss_q2            | 6.1e-05  |
# | loss_q3            | 2.47e-05 |
# | mse                | 0.00417  |
# | mse_q0             | 0.0156   |
# | mse_q1             | 0.000599 |
# | mse_q2             | 6.04e-05 |
# | mse_q3             | 2.44e-05 |
# | param_norm         | 646      |
# | samples            | 6.29e+05 |
# | step               | 7.86e+04 |
# | vb                 | 0.00045  |
# | vb_q0              | 0.00175  |
# | vb_q1              | 4.51e-06 |
# | vb_q2              | 5.6e-07  |
# | vb_q3              | 3.09e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:02:10|
# | current_grad_norm  | 0.0273   |
# | current_param_norm | 646      |
# | grad_norm          | 0.0295   |
# | lg_loss_scale      | 22.6     |
# | loss               | 0.00902  |
# | loss_q0            | 0.0321   |
# | loss_q1            | 0.000532 |
# | loss_q2            | 7.12e-05 |
# | loss_q3            | 2.82e-05 |
# | mse                | 0.0052   |
# | mse_q0             | 0.0183   |
# | mse_q1             | 0.000528 |
# | mse_q2             | 7.05e-05 |
# | mse_q3             | 2.79e-05 |
# | param_norm         | 646      |
# | samples            | 6.3e+05  |
# | step               | 7.87e+04 |
# | vb                 | 0.00382  |
# | vb_q0              | 0.0138   |
# | vb_q1              | 3.94e-06 |
# | vb_q2              | 6.47e-07 |
# | vb_q3              | 3.56e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:03:04|
# | current_grad_norm  | 0.0212   |
# | current_param_norm | 646      |
# | grad_norm          | 0.0206   |
# | lg_loss_scale      | 22.7     |
# | loss               | 0.00573  |
# | loss_q0            | 0.0209   |
# | loss_q1            | 0.000466 |
# | loss_q2            | 6.09e-05 |
# | loss_q3            | 2.11e-05 |
# | mse                | 0.00428  |
# | mse_q0             | 0.0155   |
# | mse_q1             | 0.000463 |
# | mse_q2             | 6.04e-05 |
# | mse_q3             | 2.08e-05 |
# | param_norm         | 646      |
# | samples            | 6.3e+05  |
# | step               | 7.88e+04 |
# | vb                 | 0.00145  |
# | vb_q0              | 0.00541  |
# | vb_q1              | 3.46e-06 |
# | vb_q2              | 5.5e-07  |
# | vb_q3              | 2.65e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:03:57|
# | current_grad_norm  | 0.0284   |
# | current_param_norm | 647      |
# | grad_norm          | 0.026    |
# | lg_loss_scale      | 22.8     |
# | loss               | 0.00484  |
# | loss_q0            | 0.0184   |
# | loss_q1            | 0.00045  |
# | loss_q2            | 6.58e-05 |
# | loss_q3            | 2.43e-05 |
# | mse                | 0.0043   |
# | mse_q0             | 0.0163   |
# | mse_q1             | 0.000447 |
# | mse_q2             | 6.52e-05 |
# | mse_q3             | 2.4e-05  |
# | param_norm         | 646      |
# | samples            | 6.31e+05 |
# | step               | 7.89e+04 |
# | vb                 | 0.000541 |
# | vb_q0              | 0.00211  |
# | vb_q1              | 3.34e-06 |
# | vb_q2              | 5.97e-07 |
# | vb_q3              | 3.08e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:04:51|
# | current_grad_norm  | 0.0169   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0183   |
# | lg_loss_scale      | 22.9     |
# | loss               | 0.0042   |
# | loss_q0            | 0.0162   |
# | loss_q1            | 0.000504 |
# | loss_q2            | 5.77e-05 |
# | loss_q3            | 1.88e-05 |
# | mse                | 0.00371  |
# | mse_q0             | 0.0143   |
# | mse_q1             | 0.0005   |
# | mse_q2             | 5.72e-05 |
# | mse_q3             | 1.86e-05 |
# | param_norm         | 647      |
# | samples            | 6.32e+05 |
# | step               | 7.9e+04  |
# | vb                 | 0.000497 |
# | vb_q0              | 0.00199  |
# | vb_q1              | 3.74e-06 |
# | vb_q2              | 5.25e-07 |
# | vb_q3              | 2.36e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:05:45|
# | current_grad_norm  | 0.0219   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0207   |
# | lg_loss_scale      | 23       |
# | loss               | 0.00457  |
# | loss_q0            | 0.0176   |
# | loss_q1            | 0.00049  |
# | loss_q2            | 5.08e-05 |
# | loss_q3            | 2.16e-05 |
# | mse                | 0.00348  |
# | mse_q0             | 0.0133   |
# | mse_q1             | 0.000487 |
# | mse_q2             | 5.03e-05 |
# | mse_q3             | 2.13e-05 |
# | param_norm         | 647      |
# | samples            | 6.33e+05 |
# | step               | 7.91e+04 |
# | vb                 | 0.0011   |
# | vb_q0              | 0.00436  |
# | vb_q1              | 3.63e-06 |
# | vb_q2              | 4.67e-07 |
# | vb_q3              | 2.69e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:06:39|
# | current_grad_norm  | 0.0284   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0177   |
# | lg_loss_scale      | 23.1     |
# | loss               | 0.00344  |
# | loss_q0            | 0.0124   |
# | loss_q1            | 0.000538 |
# | loss_q2            | 4.88e-05 |
# | loss_q3            | 1.86e-05 |
# | mse                | 0.00324  |
# | mse_q0             | 0.0116   |
# | mse_q1             | 0.000534 |
# | mse_q2             | 4.83e-05 |
# | mse_q3             | 1.84e-05 |
# | param_norm         | 647      |
# | samples            | 6.34e+05 |
# | step               | 7.92e+04 |
# | vb                 | 0.000209 |
# | vb_q0              | 0.000781 |
# | vb_q1              | 3.98e-06 |
# | vb_q2              | 4.49e-07 |
# | vb_q3              | 2.36e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:07:32|
# | current_grad_norm  | 0.043    |
# | current_param_norm | 647      |
# | grad_norm          | 0.0273   |
# | lg_loss_scale      | 23.2     |
# | loss               | 0.00551  |
# | loss_q0            | 0.0214   |
# | loss_q1            | 0.000473 |
# | loss_q2            | 6.22e-05 |
# | loss_q3            | 2.52e-05 |
# | mse                | 0.00408  |
# | mse_q0             | 0.0157   |
# | mse_q1             | 0.000469 |
# | mse_q2             | 6.16e-05 |
# | mse_q3             | 2.49e-05 |
# | param_norm         | 647      |
# | samples            | 6.34e+05 |
# | step               | 7.93e+04 |
# | vb                 | 0.00143  |
# | vb_q0              | 0.00569  |
# | vb_q1              | 3.5e-06  |
# | vb_q2              | 5.67e-07 |
# | vb_q3              | 3.2e-07  |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 22.333000000011406
# ---------------------------------
# |openai-2024-11-20-12:08:26|
# | current_grad_norm  | 0.0302   |
# | current_param_norm | 647      |
# | grad_norm          | 0.026    |
# | lg_loss_scale      | 22.7     |
# | loss               | 0.00558  |
# | loss_q0            | 0.0223   |
# | loss_q1            | 0.000519 |
# | loss_q2            | 6.86e-05 |
# | loss_q3            | 2.78e-05 |
# | mse                | 0.00396  |
# | mse_q0             | 0.0156   |
# | mse_q1             | 0.000516 |
# | mse_q2             | 6.8e-05  |
# | mse_q3             | 2.75e-05 |
# | param_norm         | 647      |
# | samples            | 6.35e+05 |
# | step               | 7.94e+04 |
# | vb                 | 0.00163  |
# | vb_q0              | 0.00666  |
# | vb_q1              | 3.85e-06 |
# | vb_q2              | 6.22e-07 |
# | vb_q3              | 3.6e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:09:18|
# | current_grad_norm  | 0.0202   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0346   |
# | lg_loss_scale      | 22.4     |
# | loss               | 0.0095   |
# | loss_q0            | 0.0345   |
# | loss_q1            | 0.000489 |
# | loss_q2            | 7.06e-05 |
# | loss_q3            | 3.07e-05 |
# | mse                | 0.0054   |
# | mse_q0             | 0.0194   |
# | mse_q1             | 0.000486 |
# | mse_q2             | 6.99e-05 |
# | mse_q3             | 3.03e-05 |
# | param_norm         | 647      |
# | samples            | 6.36e+05 |
# | step               | 7.95e+04 |
# | vb                 | 0.0041   |
# | vb_q0              | 0.0151   |
# | vb_q1              | 3.63e-06 |
# | vb_q2              | 6.48e-07 |
# | vb_q3              | 3.87e-07 |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:10:12|
# | current_grad_norm  | 0.0173   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0223   |
# | lg_loss_scale      | 22.5     |
# | loss               | 0.00329  |
# | loss_q0            | 0.0126   |
# | loss_q1            | 0.000496 |
# | loss_q2            | 5.96e-05 |
# | loss_q3            | 2.5e-05  |
# | mse                | 0.00303  |
# | mse_q0             | 0.0116   |
# | mse_q1             | 0.000492 |
# | mse_q2             | 5.91e-05 |
# | mse_q3             | 2.47e-05 |
# | param_norm         | 647      |
# | samples            | 6.37e+05 |
# | step               | 7.96e+04 |
# | vb                 | 0.000258 |
# | vb_q0              | 0.00103  |
# | vb_q1              | 3.66e-06 |
# | vb_q2              | 5.45e-07 |
# | vb_q3              | 3.1e-07  |
# ---------------------------------
# Found NaN, decreased lg_loss_scale to 21.61300000001175
# ---------------------------------
# |openai-2024-11-20-12:11:06|
# | current_grad_norm  | 0.0169   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0211   |
# | lg_loss_scale      | 21.8     |
# | loss               | 0.00558  |
# | loss_q0            | 0.0231   |
# | loss_q1            | 0.000452 |
# | loss_q2            | 5.96e-05 |
# | loss_q3            | 2.38e-05 |
# | mse                | 0.00347  |
# | mse_q0             | 0.0141   |
# | mse_q1             | 0.000448 |
# | mse_q2             | 5.91e-05 |
# | mse_q3             | 2.35e-05 |
# | param_norm         | 647      |
# | samples            | 6.38e+05 |
# | step               | 7.97e+04 |
# | vb                 | 0.00211  |
# | vb_q0              | 0.00898  |
# | vb_q1              | 3.35e-06 |
# | vb_q2              | 5.48e-07 |
# | vb_q3              | 3e-07    |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:12:00|
# | current_grad_norm  | 0.0498   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0228   |
# | lg_loss_scale      | 21.7     |
# | loss               | 0.00513  |
# | loss_q0            | 0.0195   |
# | loss_q1            | 0.000544 |
# | loss_q2            | 5.68e-05 |
# | loss_q3            | 2.16e-05 |
# | mse                | 0.00432  |
# | mse_q0             | 0.0163   |
# | mse_q1             | 0.00054  |
# | mse_q2             | 5.63e-05 |
# | mse_q3             | 2.13e-05 |
# | param_norm         | 647      |
# | samples            | 6.38e+05 |
# | step               | 7.98e+04 |
# | vb                 | 0.000811 |
# | vb_q0              | 0.00318  |
# | vb_q1              | 4.02e-06 |
# | vb_q2              | 5.2e-07  |
# | vb_q3              | 2.7e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:12:53|
# | current_grad_norm  | 0.0152   |
# | current_param_norm | 647      |
# | grad_norm          | 0.0238   |
# | lg_loss_scale      | 21.8     |
# | loss               | 0.00621  |
# | loss_q0            | 0.0246   |
# | loss_q1            | 0.000521 |
# | loss_q2            | 5.94e-05 |
# | loss_q3            | 2.64e-05 |
# | mse                | 0.00437  |
# | mse_q0             | 0.0171   |
# | mse_q1             | 0.000518 |
# | mse_q2             | 5.89e-05 |
# | mse_q3             | 2.6e-05  |
# | param_norm         | 647      |
# | samples            | 6.39e+05 |
# | step               | 7.99e+04 |
# | vb                 | 0.00184  |
# | vb_q0              | 0.00749  |
# | vb_q1              | 3.85e-06 |
# | vb_q2              | 5.47e-07 |
# | vb_q3              | 3.3e-07  |
# ---------------------------------
# ---------------------------------
# |openai-2024-11-20-12:13:47|
# | current_grad_norm  | 0.016    |
# | current_param_norm | 647      |
# | grad_norm          | 0.0226   |
# | lg_loss_scale      | 21.9     |
# | loss               | 0.00367  |
# | loss_q0            | 0.0142   |
# | loss_q1            | 0.000479 |
# | loss_q2            | 5.99e-05 |
# | loss_q3            | 2.18e-05 |
# | mse                | 0.00293  |
# | mse_q0             | 0.0112   |
# | mse_q1             | 0.000476 |
# | mse_q2             | 5.93e-05 |
# | mse_q3             | 2.16e-05 |
# | param_norm         | 647      |
# | samples            | 6.4e+05  |
# | step               | 8e+04    |
# | vb                 | 0.000742 |
# | vb_q0              | 0.00298  |
# | vb_q1              | 3.55e-06 |
# | vb_q2              | 5.4e-07  |
# | vb_q3              | 2.67e-07 |
# ---------------------------------
# saving model 0...
# saving model 0.9999...
# create samples
#  40%|███▉      | 396/1000 [01:07<01:42,  5.89it/s]

# %%
# Flags
MODEL_FLAGS="--cross_attention_resolutions 2,4,8 --cross_attention_windows 1,4,8 --cross_attention_shift True --video_attention_resolutions 2,4,8 --audio_attention_resolutions -1 --video_size 16,3,64,64 --audio_size 1,25600 --learn_sigma False --num_channels 128 --num_head_channels 64 --num_res_blocks 2 --resblock_updown True --use_fp16 True --use_scale_shift_norm True"

SRMODEL_FLAGS="--sr_attention_resolutions 8,16,32 --large_size 256 --small_size 64 --sr_learn_sigma True --sr_num_channels 192 --sr_num_heads 4 --sr_num_res_blocks 2 --sr_resblock_updown True --use_fp16 True --sr_use_scale_shift_norm True"

DIFFUSION_FLAGS="--diffusion_steps 1000 --noise_schedule linear --all_save_num 64 --save_type mp4 --devices 0 --batch_size 1 --is_strict True --sample_fn dpm_solver"

SR_DIFFUSION_FLAGS="--sr_diffusion_steps 1000 --sr_sample_fn ddim --sr_timestep_respacing ddim25"

# Paths
MULTIMODAL_MODEL_PATH="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug/model070000.pt"
SR_MODEL_PATH="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/sr-image-train/model080000.pt"
OUT_DIR="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/samples/multimodal-sample-sr/dpm_solver_3"
REF_PATH="/content/drive/MyDrive/environmental/train"

NUM_GPUS=1

# Run command
# !mpiexec -n $NUM_GPUS python3 /content/drive/MyDrive/MM-Diffusion/py_scripts/multimodal_sample_sr.py \
    $MODEL_FLAGS $SRMODEL_FLAGS $DIFFUSION_FLAGS $SR_DIFFUSION_FLAGS --ref_path $REF_PATH \
    --output_dir $OUT_DIR --multimodal_model_path $MULTIMODAL_MODEL_PATH --sr_model_path $SR_MODEL_PATH

# %%
REF_DIR="/content/drive/MyDrive/environmental/train"
SAMPLE_DIR="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/samples/customdata/sr_mp4"
OUTPUT_DIR="/content/drive/MyDrive/MM-Diffusion/outputs/MM-Diffusion/debug"

# %%
# !mpiexec -n 1 python /content/drive/MyDrive/MM-Diffusion/py_scripts/eval.py --devices 0 --sample_num 2048 --ref_dir "$REF_DIR" --fake_dir "$SAMPLE_DIR" --output_dir "$OUTPUT_DIR"
